# %%
import numpy as np
import pandas as pd 
import pylab as pl
from matplotlib import pyplot as plt #画图
from sklearn.cluster import KMeans 
plt.rcParams['figure.figsize'] = (16,9)
plt.style.use('ggplot')

from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# import pandas_datareader as datareader
import matplotlib.pyplot as plt
import datetime
from mpl_finance import candlestick_ohlc
# from mpl_finance import candlestick_ohlc
import matplotlib.dates as mdates

# %% [markdown]
# reading data from reading_scroll_features table and some data cleaning

# %%
data = pd.read_csv('dataa/reading_scroll_features.csv')
data = data[data['relative_time'] < 2000]

# %% [markdown]
# display how each user's reading relative time distributed.

# %%
f1 = data['relative_time'].values
print(f1.shape)
f2= data['user_id'].values
print(f2.shape)
x = np.array(list(zip(f1,f2)))
print(x.shape)
plt.scatter(f1,f2, c='black', s=7)
#filter data 1.filtered() 2.sql
# Out:
# (7692,)
# (7692,)
# (7692, 2)

# %%
# for index, row in data.iterrows():
#     if row['offset_difference'] < 0:
#         temp = row['max_offset']
#         row['max_offset'] = row['min_offset']
#        row['min_offset'] = temp
#         print(row['max_offset'],row['min_offset'],row['offset_difference'])
#         np.append([row['max_offset'],row['min_offset'],row['offset_difference']],a)
#     if row['offset_difference'] > 0:
#         np.append([row['max_offset'],row['min_offset'],row['offset_difference']],a)
#         print(row['max_offset'],row['min_offset'],row['offset_difference'])

# %% [markdown]
# display reading style by users

# %%
pd.options.display.max_rows = 1000
filtered_data =  data[(data['user_id'] == 406)]
filtered_data.head()
# Out:
#       user_id                       reading_session  article_id  max_offset  \
# 4513      406  f0cb45f0-35c9-4a3c-9755-1003967b65ea    44014076         613
# 4514      406  f0cb45f0-35c9-4a3c-9755-1003967b65ea    44014076        1919
# 4515      406  f0cb45f0-35c9-4a3c-9755-1003967b65ea    44014076        2005
# 4516      406  f0cb45f0-35c9-4a3c-9755-1003967b65ea    44014076          28
# 4517      406  f0cb45f0-35c9-4a3c-9755-1003967b65ea    44014076          34
#
#       min_offset  offset_difference  relative_time
# 4513          17                596              0
# 4514         697               1222              1
# 4515           0              -2005              2
# 4516          24                  4              3
# 4517          27                  7              5

# %%
filtered_data1 = filtered_data[(filtered_data['article_id'] ==44014076 )]
filtered_data2 = filtered_data[(filtered_data['article_id'] ==44012046 )]
filtered_data3 = filtered_data[(filtered_data['article_id'] ==43981895 )]
filtered_data4 = filtered_data[(filtered_data['article_id'] ==44010298 )]
filtered_data5 = filtered_data[(filtered_data['article_id'] ==44011112 )]
filtered_data6 = filtered_data[(filtered_data['article_id'] ==44015562 )]
filtered_data7 = filtered_data[(filtered_data['article_id'] ==44008098 )]
filtered_data8 = filtered_data[(filtered_data['article_id'] ==44020061 )]
filtered_data9 = filtered_data[(filtered_data['article_id'] ==44017266 )]
filtered_data10 = filtered_data[(filtered_data['article_id'] ==44007709 )]
filtered_data11 = filtered_data[(filtered_data['article_id'] ==43987148 )]
filtered_data12 = filtered_data[(filtered_data['article_id'] ==44021119 )]
filtered_data13 = filtered_data[(filtered_data['article_id'] ==44023381 )]
filtered_data14 = filtered_data[(filtered_data['article_id'] ==44027773 )]
filtered_data15 = filtered_data[(filtered_data['article_id'] ==44006176 )]
filtered_data16 = filtered_data[(filtered_data['article_id'] ==43968765 )]
filtered_data17 = filtered_data[(filtered_data['article_id'] ==43981165 )]

# %%
#for i in filtered_data: 
  #  if filtered_data['offset_difference'] > 0:
  ##      ohlc= filtered_data[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()
 #   else:
#        ohlc= filtered_data[['relative_time',  'min_offset','min_offset','max_offset', 'max_offset']].copy()
        
ohlc= filtered_data1[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()

f1, ax = plt.subplots(figsize = (20,10))
ax.set_xlabel('relative_time')
ax.set_ylabel('scroll_offset')
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1a24378668>,
#   <matplotlib.lines.Line2D at 0x1a24378c88>,
#   <matplotlib.lines.Line2D at 0x1a24365358>,
#   <matplotlib.lines.Line2D at 0x1a243659e8>,
#   <matplotlib.lines.Line2D at 0x1a24efc0b8>,
#   <matplotlib.lines.Line2D at 0x1a24efc748>,
#   <matplotlib.lines.Line2D at 0x1a24efcdd8>,
#   <matplotlib.lines.Line2D at 0x1a24f044a8>,
#   <matplotlib.lines.Line2D at 0x1a24f04b38>,
#   <matplotlib.lines.Line2D at 0x1a24f13208>,
#   <matplotlib.lines.Line2D at 0x1a24f13898>,
#   <matplotlib.lines.Line2D at 0x1a24f13f28>,
#   <matplotlib.lines.Line2D at 0x1a24f1d5f8>,
#   <matplotlib.lines.Line2D at 0x1a24f1dc88>,
#   <matplotlib.lines.Line2D at 0x1a24f25358>,
#   <matplotlib.lines.Line2D at 0x1a24f259e8>,
#   <matplotlib.lines.Line2D at 0x1a24f2e0b8>,
#   <matplotlib.lines.Line2D at 0x1a24f2e748>,
#   <matplotlib.lines.Line2D at 0x1a24f2edd8>,
#   <matplotlib.lines.Line2D at 0x1a24f3a4a8>,
#   <matplotlib.lines.Line2D at 0x1a24f3ab38>,
#   <matplotlib.lines.Line2D at 0x1a24f44208>,
#   <matplotlib.lines.Line2D at 0x1a24f44898>,
#   <matplotlib.lines.Line2D at 0x1a24f44f28>,
#   <matplotlib.lines.Line2D at 0x1a24f4f5f8>,
#   <matplotlib.lines.Line2D at 0x1a24f4fc88>,
#   <matplotlib.lines.Line2D at 0x1a24f5a358>,
#   <matplotlib.lines.Line2D at 0x1a24f5a9e8>,
#   <matplotlib.lines.Line2D at 0x1a24f640b8>,
#   <matplotlib.lines.Line2D at 0x1a24f64748>,
#   <matplotlib.lines.Line2D at 0x1a24f64dd8>,
#   <matplotlib.lines.Line2D at 0x1a24f6d4a8>,
#   <matplotlib.lines.Line2D at 0x1a24f6db38>,
#   <matplotlib.lines.Line2D at 0x1a24f76208>,
#   <matplotlib.lines.Line2D at 0x1a24f76898>,
#   <matplotlib.lines.Line2D at 0x1a24f76f28>,
#   <matplotlib.lines.Line2D at 0x1a24f805f8>,
#   <matplotlib.lines.Line2D at 0x1a24f80c88>,
#   <matplotlib.lines.Line2D at 0x1a24f8b358>,
#   <matplotlib.lines.Line2D at 0x1a24f8b9e8>,
#   <matplotlib.lines.Line2D at 0x1a24f960b8>,
#   <matplotlib.lines.Line2D at 0x1a24f96748>,
#   <matplotlib.lines.Line2D at 0x1a24f96dd8>,
#   <matplotlib.lines.Line2D at 0x1a24fa04a8>,
#   <matplotlib.lines.Line2D at 0x1a24fa0b38>,
#   <matplotlib.lines.Line2D at 0x1a24faa208>,
#   <matplotlib.lines.Line2D at 0x1a24faa898>,
#   <matplotlib.lines.Line2D at 0x1a24faaf28>],
#  [<matplotlib.patches.Rectangle at 0x1a243787b8>,
#   <matplotlib.patches.Rectangle at 0x1a24378e48>,
#   <matplotlib.patches.Rectangle at 0x1a24365518>,
#   <matplotlib.patches.Rectangle at 0x1a24365ba8>,
#   <matplotlib.patches.Rectangle at 0x1a24efc278>,
#   <matplotlib.patches.Rectangle at 0x1a24efc908>,
#   <matplotlib.patches.Rectangle at 0x1a24efcf98>,
#   <matplotlib.patches.Rectangle at 0x1a24f04668>,
#   <matplotlib.patches.Rectangle at 0x1a24f04cf8>,
#   <matplotlib.patches.Rectangle at 0x1a24f133c8>,
#   <matplotlib.patches.Rectangle at 0x1a24f13a58>,
#   <matplotlib.patches.Rectangle at 0x1a24f1d128>,
#   <matplotlib.patches.Rectangle at 0x1a24f1d7b8>,
#   <matplotlib.patches.Rectangle at 0x1a24f1de48>,
#   <matplotlib.patches.Rectangle at 0x1a24f25518>,
#   <matplotlib.patches.Rectangle at 0x1a24f25ba8>,
#   <matplotlib.patches.Rectangle at 0x1a24f2e278>,
#   <matplotlib.patches.Rectangle at 0x1a24f2e908>,
#   <matplotlib.patches.Rectangle at 0x1a24f2ef98>,
#   <matplotlib.patches.Rectangle at 0x1a24f3a668>,
#   <matplotlib.patches.Rectangle at 0x1a24f3acf8>,
#   <matplotlib.patches.Rectangle at 0x1a24f443c8>,
#   <matplotlib.patches.Rectangle at 0x1a24f44a58>,
#   <matplotlib.patches.Rectangle at 0x1a24f4f128>,
#   <matplotlib.patches.Rectangle at 0x1a24f4f7b8>,
#   <matplotlib.patches.Rectangle at 0x1a24f4fe48>,
#   <matplotlib.patches.Rectangle at 0x1a24f5a518>,
#   <matplotlib.patches.Rectangle at 0x1a24f5aba8>,
#   <matplotlib.patches.Rectangle at 0x1a24f64278>,
#   <matplotlib.patches.Rectangle at 0x1a24f64908>,
#   <matplotlib.patches.Rectangle at 0x1a24f64f98>,
#   <matplotlib.patches.Rectangle at 0x1a24f6d668>,
#   <matplotlib.patches.Rectangle at 0x1a24f6dcf8>,
#   <matplotlib.patches.Rectangle at 0x1a24f763c8>,
#   <matplotlib.patches.Rectangle at 0x1a24f76a58>,
#   <matplotlib.patches.Rectangle at 0x1a24f80128>,
#   <matplotlib.patches.Rectangle at 0x1a24f807b8>,
#   <matplotlib.patches.Rectangle at 0x1a24f80e48>,
#   <matplotlib.patches.Rectangle at 0x1a24f8b518>,
#   <matplotlib.patches.Rectangle at 0x1a24f8bba8>,
#   <matplotlib.patches.Rectangle at 0x1a24f96278>,
#   <matplotlib.patches.Rectangle at 0x1a24f96908>,
#   <matplotlib.patches.Rectangle at 0x1a24f96f98>,
#   <matplotlib.patches.Rectangle at 0x1a24fa0668>,
#   <matplotlib.patches.Rectangle at 0x1a24fa0cf8>,
#   <matplotlib.patches.Rectangle at 0x1a24faa3c8>,
#   <matplotlib.patches.Rectangle at 0x1a24faaa58>,
#   <matplotlib.patches.Rectangle at 0x1a24fb3128>])

# %%
ohlc= filtered_data2[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()

f1, ax = plt.subplots(figsize = (20,10))
ax.set_xlabel('relative_time')
ax.set_ylabel('scroll_offset')
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1a25023da0>,
#   <matplotlib.lines.Line2D at 0x1a25032400>,
#   <matplotlib.lines.Line2D at 0x1a25032a90>,
#   <matplotlib.lines.Line2D at 0x1a2503d160>,
#   <matplotlib.lines.Line2D at 0x1a2503d7f0>,
#   <matplotlib.lines.Line2D at 0x1a2503de80>,
#   <matplotlib.lines.Line2D at 0x1a25047550>,
#   <matplotlib.lines.Line2D at 0x1a25047be0>,
#   <matplotlib.lines.Line2D at 0x1a250512b0>,
#   <matplotlib.lines.Line2D at 0x1a25051940>,
#   <matplotlib.lines.Line2D at 0x1a25051fd0>,
#   <matplotlib.lines.Line2D at 0x1a2505a6a0>,
#   <matplotlib.lines.Line2D at 0x1a2505ad30>,
#   <matplotlib.lines.Line2D at 0x1a25064400>,
#   <matplotlib.lines.Line2D at 0x1a25064a90>,
#   <matplotlib.lines.Line2D at 0x1a2506e160>,
#   <matplotlib.lines.Line2D at 0x1a2506e7f0>,
#   <matplotlib.lines.Line2D at 0x1a2506ee80>,
#   <matplotlib.lines.Line2D at 0x1a25078550>,
#   <matplotlib.lines.Line2D at 0x1a25078be0>,
#   <matplotlib.lines.Line2D at 0x1a250822b0>,
#   <matplotlib.lines.Line2D at 0x1a25082940>,
#   <matplotlib.lines.Line2D at 0x1a25082fd0>,
#   <matplotlib.lines.Line2D at 0x1a2508c6a0>,
#   <matplotlib.lines.Line2D at 0x1a2508cd30>,
#   <matplotlib.lines.Line2D at 0x1a25097400>,
#   <matplotlib.lines.Line2D at 0x1a25097a90>,
#   <matplotlib.lines.Line2D at 0x1a250a2160>,
#   <matplotlib.lines.Line2D at 0x1a250a27f0>,
#   <matplotlib.lines.Line2D at 0x1a250a2e80>,
#   <matplotlib.lines.Line2D at 0x1a250ae550>,
#   <matplotlib.lines.Line2D at 0x1a250aebe0>,
#   <matplotlib.lines.Line2D at 0x1a250b62b0>,
#   <matplotlib.lines.Line2D at 0x1a250b6940>,
#   <matplotlib.lines.Line2D at 0x1a250b6fd0>,
#   <matplotlib.lines.Line2D at 0x1a250c16a0>,
#   <matplotlib.lines.Line2D at 0x1a250c1d30>,
#   <matplotlib.lines.Line2D at 0x1a250c9400>,
#   <matplotlib.lines.Line2D at 0x1a250c9a90>,
#   <matplotlib.lines.Line2D at 0x1a250d3160>,
#   <matplotlib.lines.Line2D at 0x1a250d37f0>,
#   <matplotlib.lines.Line2D at 0x1a250d3e80>,
#   <matplotlib.lines.Line2D at 0x1a250db550>,
#   <matplotlib.lines.Line2D at 0x1a250dbbe0>,
#   <matplotlib.lines.Line2D at 0x1a250e92b0>,
#   <matplotlib.lines.Line2D at 0x1a250e9940>,
#   <matplotlib.lines.Line2D at 0x1a250e9fd0>,
#   <matplotlib.lines.Line2D at 0x1a250f36a0>,
#   <matplotlib.lines.Line2D at 0x1a250f3d30>,
#   <matplotlib.lines.Line2D at 0x1a250fe400>,
#   <matplotlib.lines.Line2D at 0x1a250fea90>,
#   <matplotlib.lines.Line2D at 0x1a25107160>,
#   <matplotlib.lines.Line2D at 0x1a251077f0>,
#   <matplotlib.lines.Line2D at 0x1a25107e80>,
#   <matplotlib.lines.Line2D at 0x1a25113550>,
#   <matplotlib.lines.Line2D at 0x1a25113be0>,
#   <matplotlib.lines.Line2D at 0x1a2511c2b0>,
#   <matplotlib.lines.Line2D at 0x1a2511c940>,
#   <matplotlib.lines.Line2D at 0x1a2511cfd0>,
#   <matplotlib.lines.Line2D at 0x1a251276a0>,
#   <matplotlib.lines.Line2D at 0x1a25127d30>,
#   <matplotlib.lines.Line2D at 0x1a25130400>,
#   <matplotlib.lines.Line2D at 0x1a25130a90>,
#   <matplotlib.lines.Line2D at 0x1a2513a160>,
#   <matplotlib.lines.Line2D at 0x1a2513a7f0>,
#   <matplotlib.lines.Line2D at 0x1a2513ae80>,
#   <matplotlib.lines.Line2D at 0x1a25144550>,
#   <matplotlib.lines.Line2D at 0x1a25144be0>,
#   <matplotlib.lines.Line2D at 0x1a2514e2b0>,
#   <matplotlib.lines.Line2D at 0x1a2514e940>,
#   <matplotlib.lines.Line2D at 0x1a2514efd0>,
#   <matplotlib.lines.Line2D at 0x1a251596a0>,
#   <matplotlib.lines.Line2D at 0x1a25159d30>,
#   <matplotlib.lines.Line2D at 0x1a25164400>,
#   <matplotlib.lines.Line2D at 0x1a25164a90>,
#   <matplotlib.lines.Line2D at 0x1a2516e160>,
#   <matplotlib.lines.Line2D at 0x1a2516e7f0>,
#   <matplotlib.lines.Line2D at 0x1a2516ee80>,
#   <matplotlib.lines.Line2D at 0x1a25177550>,
#   <matplotlib.lines.Line2D at 0x1a25177be0>,
#   <matplotlib.lines.Line2D at 0x1a251812b0>,
#   <matplotlib.lines.Line2D at 0x1a25181940>,
#   <matplotlib.lines.Line2D at 0x1a25181fd0>,
#   <matplotlib.lines.Line2D at 0x1a2518b6a0>,
#   <matplotlib.lines.Line2D at 0x1a2518bd30>,
#   <matplotlib.lines.Line2D at 0x1a25195400>,
#   <matplotlib.lines.Line2D at 0x1a25195a90>,
#   <matplotlib.lines.Line2D at 0x1a251a2160>,
#   <matplotlib.lines.Line2D at 0x1a251a27f0>,
#   <matplotlib.lines.Line2D at 0x1a251a2e80>,
#   <matplotlib.lines.Line2D at 0x1a251ab550>,
#   <matplotlib.lines.Line2D at 0x1a251abbe0>,
#   <matplotlib.lines.Line2D at 0x1a251b52b0>,
#   <matplotlib.lines.Line2D at 0x1a251b5940>,
#   <matplotlib.lines.Line2D at 0x1a251b5fd0>,
#   <matplotlib.lines.Line2D at 0x1a251c06a0>,
#   <matplotlib.lines.Line2D at 0x1a251c0d30>,
#   <matplotlib.lines.Line2D at 0x1a251c9400>,
#   <matplotlib.lines.Line2D at 0x1a251c9a90>,
#   <matplotlib.lines.Line2D at 0x1a251d4160>,
#   <matplotlib.lines.Line2D at 0x1a251d47f0>,
#   <matplotlib.lines.Line2D at 0x1a251d4e48>,
#   <matplotlib.lines.Line2D at 0x1a251e04e0>,
#   <matplotlib.lines.Line2D at 0x1a251e0b38>,
#   <matplotlib.lines.Line2D at 0x1a251e81d0>,
#   <matplotlib.lines.Line2D at 0x1a251e8828>,
#   <matplotlib.lines.Line2D at 0x1a251e8e80>,
#   <matplotlib.lines.Line2D at 0x1a251f4518>,
#   <matplotlib.lines.Line2D at 0x1a251f4b70>,
#   <matplotlib.lines.Line2D at 0x1a251ff208>,
#   <matplotlib.lines.Line2D at 0x1a251ff860>,
#   <matplotlib.lines.Line2D at 0x1a251ffeb8>,
#   <matplotlib.lines.Line2D at 0x1a25209550>,
#   <matplotlib.lines.Line2D at 0x1a25209ba8>,
#   <matplotlib.lines.Line2D at 0x1a25214240>,
#   <matplotlib.lines.Line2D at 0x1a25214898>,
#   <matplotlib.lines.Line2D at 0x1a25214ef0>,
#   <matplotlib.lines.Line2D at 0x1a2521f588>,
#   <matplotlib.lines.Line2D at 0x1a2521fbe0>,
#   <matplotlib.lines.Line2D at 0x1a25228278>,
#   <matplotlib.lines.Line2D at 0x1a252288d0>,
#   <matplotlib.lines.Line2D at 0x1a25228f28>,
#   <matplotlib.lines.Line2D at 0x1a252335c0>,
#   <matplotlib.lines.Line2D at 0x1a25233c18>,
#   <matplotlib.lines.Line2D at 0x1a2523d2b0>,
#   <matplotlib.lines.Line2D at 0x1a2523d908>,
#   <matplotlib.lines.Line2D at 0x1a2523df60>,
#   <matplotlib.lines.Line2D at 0x1a252485f8>,
#   <matplotlib.lines.Line2D at 0x1a25248c50>,
#   <matplotlib.lines.Line2D at 0x1a252532e8>,
#   <matplotlib.lines.Line2D at 0x1a25253940>,
#   <matplotlib.lines.Line2D at 0x1a25253f98>,
#   <matplotlib.lines.Line2D at 0x1a2525c630>,
#   <matplotlib.lines.Line2D at 0x1a2525cc88>,
#   <matplotlib.lines.Line2D at 0x1a25269320>,
#   <matplotlib.lines.Line2D at 0x1a25269978>,
#   <matplotlib.lines.Line2D at 0x1a25269fd0>,
#   <matplotlib.lines.Line2D at 0x1a25274668>,
#   <matplotlib.lines.Line2D at 0x1a25274cc0>,
#   <matplotlib.lines.Line2D at 0x1a2527e358>,
#   <matplotlib.lines.Line2D at 0x1a2527e9b0>,
#   <matplotlib.lines.Line2D at 0x1a2527efd0>,
#   <matplotlib.lines.Line2D at 0x1a252876a0>,
#   <matplotlib.lines.Line2D at 0x1a25287cf8>,
#   <matplotlib.lines.Line2D at 0x1a25291390>,
#   <matplotlib.lines.Line2D at 0x1a252919e8>,
#   <matplotlib.lines.Line2D at 0x1a2529d080>,
#   <matplotlib.lines.Line2D at 0x1a2529d6d8>,
#   <matplotlib.lines.Line2D at 0x1a2529dd30>,
#   <matplotlib.lines.Line2D at 0x1a252a73c8>,
#   <matplotlib.lines.Line2D at 0x1a252a7a20>,
#   <matplotlib.lines.Line2D at 0x1a252b30b8>,
#   <matplotlib.lines.Line2D at 0x1a252b3710>,
#   <matplotlib.lines.Line2D at 0x1a252b3d68>,
#   <matplotlib.lines.Line2D at 0x1a252bc400>,
#   <matplotlib.lines.Line2D at 0x1a252bca58>,
#   <matplotlib.lines.Line2D at 0x1a252c60f0>,
#   <matplotlib.lines.Line2D at 0x1a252c6748>,
#   <matplotlib.lines.Line2D at 0x1a252c6da0>,
#   <matplotlib.lines.Line2D at 0x1a252d1438>,
#   <matplotlib.lines.Line2D at 0x1a252d1a90>,
#   <matplotlib.lines.Line2D at 0x1a252dd128>,
#   <matplotlib.lines.Line2D at 0x1a252dd780>,
#   <matplotlib.lines.Line2D at 0x1a252dddd8>,
#   <matplotlib.lines.Line2D at 0x1a252e6470>,
#   <matplotlib.lines.Line2D at 0x1a252e6ac8>,
#   <matplotlib.lines.Line2D at 0x1a252f1160>,
#   <matplotlib.lines.Line2D at 0x1a252f17b8>,
#   <matplotlib.lines.Line2D at 0x1a252f1e10>,
#   <matplotlib.lines.Line2D at 0x1a252fb4a8>,
#   <matplotlib.lines.Line2D at 0x1a252fbb00>,
#   <matplotlib.lines.Line2D at 0x1a25306198>,
#   <matplotlib.lines.Line2D at 0x1a253067f0>,
#   <matplotlib.lines.Line2D at 0x1a25306e48>,
#   <matplotlib.lines.Line2D at 0x1a253134e0>,
#   <matplotlib.lines.Line2D at 0x1a25313b38>,
#   <matplotlib.lines.Line2D at 0x1a2531b1d0>,
#   <matplotlib.lines.Line2D at 0x1a2531b828>,
#   <matplotlib.lines.Line2D at 0x1a2531be80>,
#   <matplotlib.lines.Line2D at 0x1a25327518>,
#   <matplotlib.lines.Line2D at 0x1a25327b70>,
#   <matplotlib.lines.Line2D at 0x1a25330208>,
#   <matplotlib.lines.Line2D at 0x1a25330860>],
#  [<matplotlib.patches.Rectangle at 0x1a25023ef0>,
#   <matplotlib.patches.Rectangle at 0x1a250325c0>,
#   <matplotlib.patches.Rectangle at 0x1a25032c50>,
#   <matplotlib.patches.Rectangle at 0x1a2503d320>,
#   <matplotlib.patches.Rectangle at 0x1a2503d9b0>,
#   <matplotlib.patches.Rectangle at 0x1a25047080>,
#   <matplotlib.patches.Rectangle at 0x1a25047710>,
#   <matplotlib.patches.Rectangle at 0x1a25047da0>,
#   <matplotlib.patches.Rectangle at 0x1a25051470>,
#   <matplotlib.patches.Rectangle at 0x1a25051b00>,
#   <matplotlib.patches.Rectangle at 0x1a2505a1d0>,
#   <matplotlib.patches.Rectangle at 0x1a2505a860>,
#   <matplotlib.patches.Rectangle at 0x1a2505aef0>,
#   <matplotlib.patches.Rectangle at 0x1a250645c0>,
#   <matplotlib.patches.Rectangle at 0x1a25064c50>,
#   <matplotlib.patches.Rectangle at 0x1a2506e320>,
#   <matplotlib.patches.Rectangle at 0x1a2506e9b0>,
#   <matplotlib.patches.Rectangle at 0x1a25078080>,
#   <matplotlib.patches.Rectangle at 0x1a25078710>,
#   <matplotlib.patches.Rectangle at 0x1a25078da0>,
#   <matplotlib.patches.Rectangle at 0x1a25082470>,
#   <matplotlib.patches.Rectangle at 0x1a25082b00>,
#   <matplotlib.patches.Rectangle at 0x1a2508c1d0>,
#   <matplotlib.patches.Rectangle at 0x1a2508c860>,
#   <matplotlib.patches.Rectangle at 0x1a2508cef0>,
#   <matplotlib.patches.Rectangle at 0x1a250975c0>,
#   <matplotlib.patches.Rectangle at 0x1a25097c50>,
#   <matplotlib.patches.Rectangle at 0x1a250a2320>,
#   <matplotlib.patches.Rectangle at 0x1a250a29b0>,
#   <matplotlib.patches.Rectangle at 0x1a250ae080>,
#   <matplotlib.patches.Rectangle at 0x1a250ae710>,
#   <matplotlib.patches.Rectangle at 0x1a250aeda0>,
#   <matplotlib.patches.Rectangle at 0x1a250b6470>,
#   <matplotlib.patches.Rectangle at 0x1a250b6b00>,
#   <matplotlib.patches.Rectangle at 0x1a250c11d0>,
#   <matplotlib.patches.Rectangle at 0x1a250c1860>,
#   <matplotlib.patches.Rectangle at 0x1a250c1ef0>,
#   <matplotlib.patches.Rectangle at 0x1a250c95c0>,
#   <matplotlib.patches.Rectangle at 0x1a250c9c50>,
#   <matplotlib.patches.Rectangle at 0x1a250d3320>,
#   <matplotlib.patches.Rectangle at 0x1a250d39b0>,
#   <matplotlib.patches.Rectangle at 0x1a250db080>,
#   <matplotlib.patches.Rectangle at 0x1a250db710>,
#   <matplotlib.patches.Rectangle at 0x1a250dbda0>,
#   <matplotlib.patches.Rectangle at 0x1a250e9470>,
#   <matplotlib.patches.Rectangle at 0x1a250e9b00>,
#   <matplotlib.patches.Rectangle at 0x1a250f31d0>,
#   <matplotlib.patches.Rectangle at 0x1a250f3860>,
#   <matplotlib.patches.Rectangle at 0x1a250f3ef0>,
#   <matplotlib.patches.Rectangle at 0x1a250fe5c0>,
#   <matplotlib.patches.Rectangle at 0x1a250fec50>,
#   <matplotlib.patches.Rectangle at 0x1a25107320>,
#   <matplotlib.patches.Rectangle at 0x1a251079b0>,
#   <matplotlib.patches.Rectangle at 0x1a25113080>,
#   <matplotlib.patches.Rectangle at 0x1a25113710>,
#   <matplotlib.patches.Rectangle at 0x1a25113da0>,
#   <matplotlib.patches.Rectangle at 0x1a2511c470>,
#   <matplotlib.patches.Rectangle at 0x1a2511cb00>,
#   <matplotlib.patches.Rectangle at 0x1a251271d0>,
#   <matplotlib.patches.Rectangle at 0x1a25127860>,
#   <matplotlib.patches.Rectangle at 0x1a25127ef0>,
#   <matplotlib.patches.Rectangle at 0x1a251305c0>,
#   <matplotlib.patches.Rectangle at 0x1a25130c50>,
#   <matplotlib.patches.Rectangle at 0x1a2513a320>,
#   <matplotlib.patches.Rectangle at 0x1a2513a9b0>,
#   <matplotlib.patches.Rectangle at 0x1a25144080>,
#   <matplotlib.patches.Rectangle at 0x1a25144710>,
#   <matplotlib.patches.Rectangle at 0x1a25144da0>,
#   <matplotlib.patches.Rectangle at 0x1a2514e470>,
#   <matplotlib.patches.Rectangle at 0x1a2514eb00>,
#   <matplotlib.patches.Rectangle at 0x1a251591d0>,
#   <matplotlib.patches.Rectangle at 0x1a25159860>,
#   <matplotlib.patches.Rectangle at 0x1a25159ef0>,
#   <matplotlib.patches.Rectangle at 0x1a251645c0>,
#   <matplotlib.patches.Rectangle at 0x1a25164c50>,
#   <matplotlib.patches.Rectangle at 0x1a2516e320>,
#   <matplotlib.patches.Rectangle at 0x1a2516e9b0>,
#   <matplotlib.patches.Rectangle at 0x1a25177080>,
#   <matplotlib.patches.Rectangle at 0x1a25177710>,
#   <matplotlib.patches.Rectangle at 0x1a25177da0>,
#   <matplotlib.patches.Rectangle at 0x1a25181470>,
#   <matplotlib.patches.Rectangle at 0x1a25181b00>,
#   <matplotlib.patches.Rectangle at 0x1a2518b1d0>,
#   <matplotlib.patches.Rectangle at 0x1a2518b860>,
#   <matplotlib.patches.Rectangle at 0x1a2518bef0>,
#   <matplotlib.patches.Rectangle at 0x1a251955c0>,
#   <matplotlib.patches.Rectangle at 0x1a25195c50>,
#   <matplotlib.patches.Rectangle at 0x1a251a2320>,
#   <matplotlib.patches.Rectangle at 0x1a251a29b0>,
#   <matplotlib.patches.Rectangle at 0x1a251ab080>,
#   <matplotlib.patches.Rectangle at 0x1a251ab710>,
#   <matplotlib.patches.Rectangle at 0x1a251abda0>,
#   <matplotlib.patches.Rectangle at 0x1a251b5470>,
#   <matplotlib.patches.Rectangle at 0x1a251b5b00>,
#   <matplotlib.patches.Rectangle at 0x1a251c01d0>,
#   <matplotlib.patches.Rectangle at 0x1a251c0860>,
#   <matplotlib.patches.Rectangle at 0x1a251c0ef0>,
#   <matplotlib.patches.Rectangle at 0x1a251c95c0>,
#   <matplotlib.patches.Rectangle at 0x1a251c9c50>,
#   <matplotlib.patches.Rectangle at 0x1a251d4320>,
#   <matplotlib.patches.Rectangle at 0x1a251d49b0>,
#   <matplotlib.patches.Rectangle at 0x1a251e0048>,
#   <matplotlib.patches.Rectangle at 0x1a251e06a0>,
#   <matplotlib.patches.Rectangle at 0x1a251e0cf8>,
#   <matplotlib.patches.Rectangle at 0x1a251e8390>,
#   <matplotlib.patches.Rectangle at 0x1a251e89e8>,
#   <matplotlib.patches.Rectangle at 0x1a251f4080>,
#   <matplotlib.patches.Rectangle at 0x1a251f46d8>,
#   <matplotlib.patches.Rectangle at 0x1a251f4d30>,
#   <matplotlib.patches.Rectangle at 0x1a251ff3c8>,
#   <matplotlib.patches.Rectangle at 0x1a251ffa20>,
#   <matplotlib.patches.Rectangle at 0x1a252090b8>,
#   <matplotlib.patches.Rectangle at 0x1a25209710>,
#   <matplotlib.patches.Rectangle at 0x1a25209d68>,
#   <matplotlib.patches.Rectangle at 0x1a25214400>,
#   <matplotlib.patches.Rectangle at 0x1a25214a58>,
#   <matplotlib.patches.Rectangle at 0x1a2521f0f0>,
#   <matplotlib.patches.Rectangle at 0x1a2521f748>,
#   <matplotlib.patches.Rectangle at 0x1a2521fda0>,
#   <matplotlib.patches.Rectangle at 0x1a25228438>,
#   <matplotlib.patches.Rectangle at 0x1a25228a90>,
#   <matplotlib.patches.Rectangle at 0x1a25233128>,
#   <matplotlib.patches.Rectangle at 0x1a25233780>,
#   <matplotlib.patches.Rectangle at 0x1a25233dd8>,
#   <matplotlib.patches.Rectangle at 0x1a2523d470>,
#   <matplotlib.patches.Rectangle at 0x1a2523dac8>,
#   <matplotlib.patches.Rectangle at 0x1a25248160>,
#   <matplotlib.patches.Rectangle at 0x1a252487b8>,
#   <matplotlib.patches.Rectangle at 0x1a25248e10>,
#   <matplotlib.patches.Rectangle at 0x1a252534a8>,
#   <matplotlib.patches.Rectangle at 0x1a25253b00>,
#   <matplotlib.patches.Rectangle at 0x1a2525c198>,
#   <matplotlib.patches.Rectangle at 0x1a2525c7f0>,
#   <matplotlib.patches.Rectangle at 0x1a2525ce48>,
#   <matplotlib.patches.Rectangle at 0x1a252694e0>,
#   <matplotlib.patches.Rectangle at 0x1a25269b38>,
#   <matplotlib.patches.Rectangle at 0x1a252741d0>,
#   <matplotlib.patches.Rectangle at 0x1a25274828>,
#   <matplotlib.patches.Rectangle at 0x1a25274e80>,
#   <matplotlib.patches.Rectangle at 0x1a2527e518>,
#   <matplotlib.patches.Rectangle at 0x1a2527eb70>,
#   <matplotlib.patches.Rectangle at 0x1a25287208>,
#   <matplotlib.patches.Rectangle at 0x1a25287860>,
#   <matplotlib.patches.Rectangle at 0x1a25287eb8>,
#   <matplotlib.patches.Rectangle at 0x1a25291550>,
#   <matplotlib.patches.Rectangle at 0x1a25291ba8>,
#   <matplotlib.patches.Rectangle at 0x1a2529d240>,
#   <matplotlib.patches.Rectangle at 0x1a2529d898>,
#   <matplotlib.patches.Rectangle at 0x1a2529def0>,
#   <matplotlib.patches.Rectangle at 0x1a252a7588>,
#   <matplotlib.patches.Rectangle at 0x1a252a7be0>,
#   <matplotlib.patches.Rectangle at 0x1a252b3278>,
#   <matplotlib.patches.Rectangle at 0x1a252b38d0>,
#   <matplotlib.patches.Rectangle at 0x1a252b3f28>,
#   <matplotlib.patches.Rectangle at 0x1a252bc5c0>,
#   <matplotlib.patches.Rectangle at 0x1a252bcc18>,
#   <matplotlib.patches.Rectangle at 0x1a252c62b0>,
#   <matplotlib.patches.Rectangle at 0x1a252c6908>,
#   <matplotlib.patches.Rectangle at 0x1a252c6f60>,
#   <matplotlib.patches.Rectangle at 0x1a252d15f8>,
#   <matplotlib.patches.Rectangle at 0x1a252d1c50>,
#   <matplotlib.patches.Rectangle at 0x1a252dd2e8>,
#   <matplotlib.patches.Rectangle at 0x1a252dd940>,
#   <matplotlib.patches.Rectangle at 0x1a252ddf98>,
#   <matplotlib.patches.Rectangle at 0x1a252e6630>,
#   <matplotlib.patches.Rectangle at 0x1a252e6c88>,
#   <matplotlib.patches.Rectangle at 0x1a252f1320>,
#   <matplotlib.patches.Rectangle at 0x1a252f1978>,
#   <matplotlib.patches.Rectangle at 0x1a252f1fd0>,
#   <matplotlib.patches.Rectangle at 0x1a252fb668>,
#   <matplotlib.patches.Rectangle at 0x1a252fbcc0>,
#   <matplotlib.patches.Rectangle at 0x1a25306358>,
#   <matplotlib.patches.Rectangle at 0x1a253069b0>,
#   <matplotlib.patches.Rectangle at 0x1a25313048>,
#   <matplotlib.patches.Rectangle at 0x1a253136a0>,
#   <matplotlib.patches.Rectangle at 0x1a25313cf8>,
#   <matplotlib.patches.Rectangle at 0x1a2531b390>,
#   <matplotlib.patches.Rectangle at 0x1a2531b9e8>,
#   <matplotlib.patches.Rectangle at 0x1a25327080>,
#   <matplotlib.patches.Rectangle at 0x1a253276d8>,
#   <matplotlib.patches.Rectangle at 0x1a25327d30>,
#   <matplotlib.patches.Rectangle at 0x1a253303c8>,
#   <matplotlib.patches.Rectangle at 0x1a25330a20>])

# %%
ohlc= filtered_data3[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()

f1, ax = plt.subplots(figsize = (20,10))
ax.set_xlabel('relative_time')
ax.set_ylabel('scroll_offset')
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1a254038d0>,
#   <matplotlib.lines.Line2D at 0x1a25403ef0>,
#   <matplotlib.lines.Line2D at 0x1a253ff5c0>,
#   <matplotlib.lines.Line2D at 0x1a253ffc50>,
#   <matplotlib.lines.Line2D at 0x1a253fb320>,
#   <matplotlib.lines.Line2D at 0x1a253fb9b0>,
#   <matplotlib.lines.Line2D at 0x1a253d7080>,
#   <matplotlib.lines.Line2D at 0x1a253d7710>,
#   <matplotlib.lines.Line2D at 0x1a253d7da0>,
#   <matplotlib.lines.Line2D at 0x1a253db470>,
#   <matplotlib.lines.Line2D at 0x1a253dbb00>,
#   <matplotlib.lines.Line2D at 0x1a253e71d0>,
#   <matplotlib.lines.Line2D at 0x1a253e7860>,
#   <matplotlib.lines.Line2D at 0x1a253e7ef0>,
#   <matplotlib.lines.Line2D at 0x1a254155c0>,
#   <matplotlib.lines.Line2D at 0x1a25415c50>,
#   <matplotlib.lines.Line2D at 0x1a2541e320>,
#   <matplotlib.lines.Line2D at 0x1a2541e9b0>,
#   <matplotlib.lines.Line2D at 0x1a2542a080>,
#   <matplotlib.lines.Line2D at 0x1a2542a710>,
#   <matplotlib.lines.Line2D at 0x1a2542ada0>,
#   <matplotlib.lines.Line2D at 0x1a25445470>,
#   <matplotlib.lines.Line2D at 0x1a25445b00>,
#   <matplotlib.lines.Line2D at 0x1a2544d1d0>,
#   <matplotlib.lines.Line2D at 0x1a2544d860>,
#   <matplotlib.lines.Line2D at 0x1a2544def0>,
#   <matplotlib.lines.Line2D at 0x1a254565c0>,
#   <matplotlib.lines.Line2D at 0x1a25456c50>,
#   <matplotlib.lines.Line2D at 0x1a25461320>,
#   <matplotlib.lines.Line2D at 0x1a254619b0>,
#   <matplotlib.lines.Line2D at 0x1a2546b080>,
#   <matplotlib.lines.Line2D at 0x1a2546b710>,
#   <matplotlib.lines.Line2D at 0x1a2546bda0>,
#   <matplotlib.lines.Line2D at 0x1a25475470>,
#   <matplotlib.lines.Line2D at 0x1a25475b00>,
#   <matplotlib.lines.Line2D at 0x1a254811d0>,
#   <matplotlib.lines.Line2D at 0x1a25481860>,
#   <matplotlib.lines.Line2D at 0x1a25481ef0>,
#   <matplotlib.lines.Line2D at 0x1a2548a5c0>,
#   <matplotlib.lines.Line2D at 0x1a2548ac50>,
#   <matplotlib.lines.Line2D at 0x1a25494320>],
#  [<matplotlib.patches.Rectangle at 0x1a25403a20>,
#   <matplotlib.patches.Rectangle at 0x1a253ff0f0>,
#   <matplotlib.patches.Rectangle at 0x1a253ff780>,
#   <matplotlib.patches.Rectangle at 0x1a253ffe10>,
#   <matplotlib.patches.Rectangle at 0x1a253fb4e0>,
#   <matplotlib.patches.Rectangle at 0x1a253fbb70>,
#   <matplotlib.patches.Rectangle at 0x1a253d7240>,
#   <matplotlib.patches.Rectangle at 0x1a253d78d0>,
#   <matplotlib.patches.Rectangle at 0x1a253d7f60>,
#   <matplotlib.patches.Rectangle at 0x1a253db630>,
#   <matplotlib.patches.Rectangle at 0x1a253dbcc0>,
#   <matplotlib.patches.Rectangle at 0x1a253e7390>,
#   <matplotlib.patches.Rectangle at 0x1a253e7a20>,
#   <matplotlib.patches.Rectangle at 0x1a254150f0>,
#   <matplotlib.patches.Rectangle at 0x1a25415780>,
#   <matplotlib.patches.Rectangle at 0x1a25415e10>,
#   <matplotlib.patches.Rectangle at 0x1a2541e4e0>,
#   <matplotlib.patches.Rectangle at 0x1a2541eb70>,
#   <matplotlib.patches.Rectangle at 0x1a2542a240>,
#   <matplotlib.patches.Rectangle at 0x1a2542a8d0>,
#   <matplotlib.patches.Rectangle at 0x1a2542af60>,
#   <matplotlib.patches.Rectangle at 0x1a25445630>,
#   <matplotlib.patches.Rectangle at 0x1a25445cc0>,
#   <matplotlib.patches.Rectangle at 0x1a2544d390>,
#   <matplotlib.patches.Rectangle at 0x1a2544da20>,
#   <matplotlib.patches.Rectangle at 0x1a254560f0>,
#   <matplotlib.patches.Rectangle at 0x1a25456780>,
#   <matplotlib.patches.Rectangle at 0x1a25456e10>,
#   <matplotlib.patches.Rectangle at 0x1a254614e0>,
#   <matplotlib.patches.Rectangle at 0x1a25461b70>,
#   <matplotlib.patches.Rectangle at 0x1a2546b240>,
#   <matplotlib.patches.Rectangle at 0x1a2546b8d0>,
#   <matplotlib.patches.Rectangle at 0x1a2546bf60>,
#   <matplotlib.patches.Rectangle at 0x1a25475630>,
#   <matplotlib.patches.Rectangle at 0x1a25475cc0>,
#   <matplotlib.patches.Rectangle at 0x1a25481390>,
#   <matplotlib.patches.Rectangle at 0x1a25481a20>,
#   <matplotlib.patches.Rectangle at 0x1a2548a0f0>,
#   <matplotlib.patches.Rectangle at 0x1a2548a780>,
#   <matplotlib.patches.Rectangle at 0x1a2548ae10>,
#   <matplotlib.patches.Rectangle at 0x1a254944e0>])

# %%
ohlc= filtered_data4[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()

f1, ax = plt.subplots(figsize = (20,10))
ax.set_xlabel('relative_time')
ax.set_ylabel('scroll_offset')
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1a257c5908>,
#   <matplotlib.lines.Line2D at 0x1a257c5f28>,
#   <matplotlib.lines.Line2D at 0x1a257cd5f8>,
#   <matplotlib.lines.Line2D at 0x1a257cdc88>,
#   <matplotlib.lines.Line2D at 0x1a257d7358>,
#   <matplotlib.lines.Line2D at 0x1a257d79e8>,
#   <matplotlib.lines.Line2D at 0x1a257e10b8>,
#   <matplotlib.lines.Line2D at 0x1a257e1748>,
#   <matplotlib.lines.Line2D at 0x1a257e1dd8>,
#   <matplotlib.lines.Line2D at 0x1a257eb4a8>,
#   <matplotlib.lines.Line2D at 0x1a257ebb38>,
#   <matplotlib.lines.Line2D at 0x1a257f4208>,
#   <matplotlib.lines.Line2D at 0x1a257f4898>,
#   <matplotlib.lines.Line2D at 0x1a257f4f28>,
#   <matplotlib.lines.Line2D at 0x1a258005f8>,
#   <matplotlib.lines.Line2D at 0x1a25800c88>,
#   <matplotlib.lines.Line2D at 0x1a2580a358>],
#  [<matplotlib.patches.Rectangle at 0x1a257c5a58>,
#   <matplotlib.patches.Rectangle at 0x1a257cd128>,
#   <matplotlib.patches.Rectangle at 0x1a257cd7b8>,
#   <matplotlib.patches.Rectangle at 0x1a257cde48>,
#   <matplotlib.patches.Rectangle at 0x1a257d7518>,
#   <matplotlib.patches.Rectangle at 0x1a257d7ba8>,
#   <matplotlib.patches.Rectangle at 0x1a257e1278>,
#   <matplotlib.patches.Rectangle at 0x1a257e1908>,
#   <matplotlib.patches.Rectangle at 0x1a257e1f98>,
#   <matplotlib.patches.Rectangle at 0x1a257eb668>,
#   <matplotlib.patches.Rectangle at 0x1a257ebcf8>,
#   <matplotlib.patches.Rectangle at 0x1a257f43c8>,
#   <matplotlib.patches.Rectangle at 0x1a257f4a58>,
#   <matplotlib.patches.Rectangle at 0x1a25800128>,
#   <matplotlib.patches.Rectangle at 0x1a258007b8>,
#   <matplotlib.patches.Rectangle at 0x1a25800e48>,
#   <matplotlib.patches.Rectangle at 0x1a2580a518>])

# %%
ohlc= filtered_data5[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()

f1, ax = plt.subplots(figsize = (20,10))
ax.set_xlabel('relative_time')
ax.set_ylabel('scroll_offset')
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1a2587ab38>,
#   <matplotlib.lines.Line2D at 0x1a25b35198>,
#   <matplotlib.lines.Line2D at 0x1a25b35828>,
#   <matplotlib.lines.Line2D at 0x1a25b35eb8>,
#   <matplotlib.lines.Line2D at 0x1a25b3e588>,
#   <matplotlib.lines.Line2D at 0x1a25b3ec18>,
#   <matplotlib.lines.Line2D at 0x1a25b482e8>,
#   <matplotlib.lines.Line2D at 0x1a25b48978>,
#   <matplotlib.lines.Line2D at 0x1a25b48fd0>,
#   <matplotlib.lines.Line2D at 0x1a25b516d8>],
#  [<matplotlib.patches.Rectangle at 0x1a2587ac88>,
#   <matplotlib.patches.Rectangle at 0x1a25b35358>,
#   <matplotlib.patches.Rectangle at 0x1a25b359e8>,
#   <matplotlib.patches.Rectangle at 0x1a25b3e0b8>,
#   <matplotlib.patches.Rectangle at 0x1a25b3e748>,
#   <matplotlib.patches.Rectangle at 0x1a25b3edd8>,
#   <matplotlib.patches.Rectangle at 0x1a25b484a8>,
#   <matplotlib.patches.Rectangle at 0x1a25b48b38>,
#   <matplotlib.patches.Rectangle at 0x1a25b51208>,
#   <matplotlib.patches.Rectangle at 0x1a25b51898>])

# %%
ohlc= filtered_data6[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()

f1, ax = plt.subplots(figsize = (20,10))
ax.set_xlabel('relative_time')
ax.set_ylabel('scroll_offset')
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1a25e6d0f0>,
#   <matplotlib.lines.Line2D at 0x1a25e6d710>,
#   <matplotlib.lines.Line2D at 0x1a25e6dda0>,
#   <matplotlib.lines.Line2D at 0x1a25e77470>,
#   <matplotlib.lines.Line2D at 0x1a25e77b00>,
#   <matplotlib.lines.Line2D at 0x1a25e801d0>,
#   <matplotlib.lines.Line2D at 0x1a25e80860>,
#   <matplotlib.lines.Line2D at 0x1a25e80ef0>,
#   <matplotlib.lines.Line2D at 0x1a25e8a5c0>,
#   <matplotlib.lines.Line2D at 0x1a25e8ac50>,
#   <matplotlib.lines.Line2D at 0x1a25e94320>,
#   <matplotlib.lines.Line2D at 0x1a25e949b0>,
#   <matplotlib.lines.Line2D at 0x1a25e9f080>,
#   <matplotlib.lines.Line2D at 0x1a25e9f710>,
#   <matplotlib.lines.Line2D at 0x1a25e9fda0>,
#   <matplotlib.lines.Line2D at 0x1a25ea6470>,
#   <matplotlib.lines.Line2D at 0x1a25ea6b00>,
#   <matplotlib.lines.Line2D at 0x1a25eb11d0>,
#   <matplotlib.lines.Line2D at 0x1a25eb1860>],
#  [<matplotlib.patches.Rectangle at 0x1a25e6d240>,
#   <matplotlib.patches.Rectangle at 0x1a25e6d8d0>,
#   <matplotlib.patches.Rectangle at 0x1a25e6df60>,
#   <matplotlib.patches.Rectangle at 0x1a25e77630>,
#   <matplotlib.patches.Rectangle at 0x1a25e77cc0>,
#   <matplotlib.patches.Rectangle at 0x1a25e80390>,
#   <matplotlib.patches.Rectangle at 0x1a25e80a20>,
#   <matplotlib.patches.Rectangle at 0x1a25e8a0f0>,
#   <matplotlib.patches.Rectangle at 0x1a25e8a780>,
#   <matplotlib.patches.Rectangle at 0x1a25e8ae10>,
#   <matplotlib.patches.Rectangle at 0x1a25e944e0>,
#   <matplotlib.patches.Rectangle at 0x1a25e94b70>,
#   <matplotlib.patches.Rectangle at 0x1a25e9f240>,
#   <matplotlib.patches.Rectangle at 0x1a25e9f8d0>,
#   <matplotlib.patches.Rectangle at 0x1a25e9ff60>,
#   <matplotlib.patches.Rectangle at 0x1a25ea6630>,
#   <matplotlib.patches.Rectangle at 0x1a25ea6cc0>,
#   <matplotlib.patches.Rectangle at 0x1a25eb1390>,
#   <matplotlib.patches.Rectangle at 0x1a25eb1a20>])

# %%
ohlc= filtered_data7[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()

f1, ax = plt.subplots(figsize = (20,10))
ax.set_xlabel('relative_time')
ax.set_ylabel('scroll_offset')
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1a261d9518>,
#   <matplotlib.lines.Line2D at 0x1a261d9b38>,
#   <matplotlib.lines.Line2D at 0x1a25f1a208>,
#   <matplotlib.lines.Line2D at 0x1a25f1a898>,
#   <matplotlib.lines.Line2D at 0x1a25f1af28>,
#   <matplotlib.lines.Line2D at 0x1a261eb5f8>,
#   <matplotlib.lines.Line2D at 0x1a261ebc88>,
#   <matplotlib.lines.Line2D at 0x1a261f2358>,
#   <matplotlib.lines.Line2D at 0x1a261f29e8>,
#   <matplotlib.lines.Line2D at 0x1a261fc0b8>,
#   <matplotlib.lines.Line2D at 0x1a261fc748>,
#   <matplotlib.lines.Line2D at 0x1a261fcdd8>,
#   <matplotlib.lines.Line2D at 0x1a262054a8>],
#  [<matplotlib.patches.Rectangle at 0x1a261d9668>,
#   <matplotlib.patches.Rectangle at 0x1a261d9cf8>,
#   <matplotlib.patches.Rectangle at 0x1a25f1a3c8>,
#   <matplotlib.patches.Rectangle at 0x1a25f1aa58>,
#   <matplotlib.patches.Rectangle at 0x1a261eb128>,
#   <matplotlib.patches.Rectangle at 0x1a261eb7b8>,
#   <matplotlib.patches.Rectangle at 0x1a261ebe48>,
#   <matplotlib.patches.Rectangle at 0x1a261f2518>,
#   <matplotlib.patches.Rectangle at 0x1a261f2ba8>,
#   <matplotlib.patches.Rectangle at 0x1a261fc278>,
#   <matplotlib.patches.Rectangle at 0x1a261fc908>,
#   <matplotlib.patches.Rectangle at 0x1a261fcf98>,
#   <matplotlib.patches.Rectangle at 0x1a26205668>])

# %%
ohlc= filtered_data8[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()

f1, ax = plt.subplots(figsize = (20,10))
ax.set_xlabel('relative_time')
ax.set_ylabel('scroll_offset')
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1a26270f28>,
#   <matplotlib.lines.Line2D at 0x1a26279588>,
#   <matplotlib.lines.Line2D at 0x1a26279c18>,
#   <matplotlib.lines.Line2D at 0x1a262812e8>,
#   <matplotlib.lines.Line2D at 0x1a26281978>,
#   <matplotlib.lines.Line2D at 0x1a26281fd0>,
#   <matplotlib.lines.Line2D at 0x1a2628d6d8>,
#   <matplotlib.lines.Line2D at 0x1a2628dd68>,
#   <matplotlib.lines.Line2D at 0x1a26546438>,
#   <matplotlib.lines.Line2D at 0x1a26546ac8>,
#   <matplotlib.lines.Line2D at 0x1a2654f198>,
#   <matplotlib.lines.Line2D at 0x1a2654f828>,
#   <matplotlib.lines.Line2D at 0x1a2654feb8>,
#   <matplotlib.lines.Line2D at 0x1a26559588>,
#   <matplotlib.lines.Line2D at 0x1a26559c18>,
#   <matplotlib.lines.Line2D at 0x1a265612e8>,
#   <matplotlib.lines.Line2D at 0x1a26561978>],
#  [<matplotlib.patches.Rectangle at 0x1a262790b8>,
#   <matplotlib.patches.Rectangle at 0x1a26279748>,
#   <matplotlib.patches.Rectangle at 0x1a26279dd8>,
#   <matplotlib.patches.Rectangle at 0x1a262814a8>,
#   <matplotlib.patches.Rectangle at 0x1a26281b38>,
#   <matplotlib.patches.Rectangle at 0x1a2628d208>,
#   <matplotlib.patches.Rectangle at 0x1a2628d898>,
#   <matplotlib.patches.Rectangle at 0x1a2628df28>,
#   <matplotlib.patches.Rectangle at 0x1a265465f8>,
#   <matplotlib.patches.Rectangle at 0x1a26546c88>,
#   <matplotlib.patches.Rectangle at 0x1a2654f358>,
#   <matplotlib.patches.Rectangle at 0x1a2654f9e8>,
#   <matplotlib.patches.Rectangle at 0x1a265590b8>,
#   <matplotlib.patches.Rectangle at 0x1a26559748>,
#   <matplotlib.patches.Rectangle at 0x1a26559dd8>,
#   <matplotlib.patches.Rectangle at 0x1a265614a8>,
#   <matplotlib.patches.Rectangle at 0x1a26561b38>])

# %%
ohlc= filtered_data9[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()

f1, ax = plt.subplots(figsize = (20,10))
ax.set_xlabel('relative_time')
ax.set_ylabel('scroll_offset')
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1a265dc160>,
#   <matplotlib.lines.Line2D at 0x1a265dc780>,
#   <matplotlib.lines.Line2D at 0x1a265dce10>,
#   <matplotlib.lines.Line2D at 0x1a265e84e0>,
#   <matplotlib.lines.Line2D at 0x1a265e8b70>,
#   <matplotlib.lines.Line2D at 0x1a265f1240>,
#   <matplotlib.lines.Line2D at 0x1a265f18d0>,
#   <matplotlib.lines.Line2D at 0x1a265f1f60>,
#   <matplotlib.lines.Line2D at 0x1a265fb630>,
#   <matplotlib.lines.Line2D at 0x1a265fbcc0>,
#   <matplotlib.lines.Line2D at 0x1a268b3390>,
#   <matplotlib.lines.Line2D at 0x1a268b3a20>,
#   <matplotlib.lines.Line2D at 0x1a268bc0f0>,
#   <matplotlib.lines.Line2D at 0x1a268bc780>,
#   <matplotlib.lines.Line2D at 0x1a268bce10>,
#   <matplotlib.lines.Line2D at 0x1a268c64e0>,
#   <matplotlib.lines.Line2D at 0x1a268c6b70>,
#   <matplotlib.lines.Line2D at 0x1a268d2240>,
#   <matplotlib.lines.Line2D at 0x1a268d28d0>,
#   <matplotlib.lines.Line2D at 0x1a268d2f60>,
#   <matplotlib.lines.Line2D at 0x1a268dc630>,
#   <matplotlib.lines.Line2D at 0x1a268dccc0>,
#   <matplotlib.lines.Line2D at 0x1a268e4390>,
#   <matplotlib.lines.Line2D at 0x1a268e4a20>,
#   <matplotlib.lines.Line2D at 0x1a268f00f0>,
#   <matplotlib.lines.Line2D at 0x1a268f0780>,
#   <matplotlib.lines.Line2D at 0x1a268f0e10>,
#   <matplotlib.lines.Line2D at 0x1a268fb4e0>,
#   <matplotlib.lines.Line2D at 0x1a268fbb70>,
#   <matplotlib.lines.Line2D at 0x1a26904240>,
#   <matplotlib.lines.Line2D at 0x1a269048d0>,
#   <matplotlib.lines.Line2D at 0x1a26904f60>,
#   <matplotlib.lines.Line2D at 0x1a26911630>,
#   <matplotlib.lines.Line2D at 0x1a26911cc0>,
#   <matplotlib.lines.Line2D at 0x1a2691a390>,
#   <matplotlib.lines.Line2D at 0x1a2691aa20>,
#   <matplotlib.lines.Line2D at 0x1a269250f0>,
#   <matplotlib.lines.Line2D at 0x1a26925780>,
#   <matplotlib.lines.Line2D at 0x1a26925e10>,
#   <matplotlib.lines.Line2D at 0x1a2692e4e0>,
#   <matplotlib.lines.Line2D at 0x1a2692eb70>,
#   <matplotlib.lines.Line2D at 0x1a26938240>,
#   <matplotlib.lines.Line2D at 0x1a269388d0>,
#   <matplotlib.lines.Line2D at 0x1a26938f60>,
#   <matplotlib.lines.Line2D at 0x1a26941630>,
#   <matplotlib.lines.Line2D at 0x1a26941cc0>,
#   <matplotlib.lines.Line2D at 0x1a2694c390>,
#   <matplotlib.lines.Line2D at 0x1a2694ca20>,
#   <matplotlib.lines.Line2D at 0x1a269570f0>,
#   <matplotlib.lines.Line2D at 0x1a26957780>,
#   <matplotlib.lines.Line2D at 0x1a26957e10>,
#   <matplotlib.lines.Line2D at 0x1a269614e0>,
#   <matplotlib.lines.Line2D at 0x1a26961b70>,
#   <matplotlib.lines.Line2D at 0x1a2696a240>,
#   <matplotlib.lines.Line2D at 0x1a2696a8d0>,
#   <matplotlib.lines.Line2D at 0x1a2696af60>,
#   <matplotlib.lines.Line2D at 0x1a26976630>,
#   <matplotlib.lines.Line2D at 0x1a26976cc0>,
#   <matplotlib.lines.Line2D at 0x1a26980390>,
#   <matplotlib.lines.Line2D at 0x1a26980a20>,
#   <matplotlib.lines.Line2D at 0x1a2698a0f0>,
#   <matplotlib.lines.Line2D at 0x1a2698a780>,
#   <matplotlib.lines.Line2D at 0x1a2698ae10>,
#   <matplotlib.lines.Line2D at 0x1a269934e0>,
#   <matplotlib.lines.Line2D at 0x1a26993b70>,
#   <matplotlib.lines.Line2D at 0x1a2699d240>,
#   <matplotlib.lines.Line2D at 0x1a2699d8d0>,
#   <matplotlib.lines.Line2D at 0x1a2699df60>,
#   <matplotlib.lines.Line2D at 0x1a269a7630>,
#   <matplotlib.lines.Line2D at 0x1a269a7cc0>,
#   <matplotlib.lines.Line2D at 0x1a269b3390>,
#   <matplotlib.lines.Line2D at 0x1a269b3a20>,
#   <matplotlib.lines.Line2D at 0x1a269bd0f0>,
#   <matplotlib.lines.Line2D at 0x1a269bd780>,
#   <matplotlib.lines.Line2D at 0x1a269bde10>,
#   <matplotlib.lines.Line2D at 0x1a269c74e0>,
#   <matplotlib.lines.Line2D at 0x1a269c7b70>,
#   <matplotlib.lines.Line2D at 0x1a269d1240>,
#   <matplotlib.lines.Line2D at 0x1a269d18d0>,
#   <matplotlib.lines.Line2D at 0x1a269d1f60>,
#   <matplotlib.lines.Line2D at 0x1a269dc630>,
#   <matplotlib.lines.Line2D at 0x1a269dccc0>,
#   <matplotlib.lines.Line2D at 0x1a269e4390>,
#   <matplotlib.lines.Line2D at 0x1a269e4a20>,
#   <matplotlib.lines.Line2D at 0x1a269ee0f0>,
#   <matplotlib.lines.Line2D at 0x1a269ee780>,
#   <matplotlib.lines.Line2D at 0x1a269eee10>,
#   <matplotlib.lines.Line2D at 0x1a269f94e0>,
#   <matplotlib.lines.Line2D at 0x1a269f9b70>,
#   <matplotlib.lines.Line2D at 0x1a26a05240>],
#  [<matplotlib.patches.Rectangle at 0x1a265dc2b0>,
#   <matplotlib.patches.Rectangle at 0x1a265dc940>,
#   <matplotlib.patches.Rectangle at 0x1a265dcfd0>,
#   <matplotlib.patches.Rectangle at 0x1a265e86a0>,
#   <matplotlib.patches.Rectangle at 0x1a265e8d30>,
#   <matplotlib.patches.Rectangle at 0x1a265f1400>,
#   <matplotlib.patches.Rectangle at 0x1a265f1a90>,
#   <matplotlib.patches.Rectangle at 0x1a265fb160>,
#   <matplotlib.patches.Rectangle at 0x1a265fb7f0>,
#   <matplotlib.patches.Rectangle at 0x1a265fbe80>,
#   <matplotlib.patches.Rectangle at 0x1a268b3550>,
#   <matplotlib.patches.Rectangle at 0x1a268b3be0>,
#   <matplotlib.patches.Rectangle at 0x1a268bc2b0>,
#   <matplotlib.patches.Rectangle at 0x1a268bc940>,
#   <matplotlib.patches.Rectangle at 0x1a268bcfd0>,
#   <matplotlib.patches.Rectangle at 0x1a268c66a0>,
#   <matplotlib.patches.Rectangle at 0x1a268c6d30>,
#   <matplotlib.patches.Rectangle at 0x1a268d2400>,
#   <matplotlib.patches.Rectangle at 0x1a268d2a90>,
#   <matplotlib.patches.Rectangle at 0x1a268dc160>,
#   <matplotlib.patches.Rectangle at 0x1a268dc7f0>,
#   <matplotlib.patches.Rectangle at 0x1a268dce80>,
#   <matplotlib.patches.Rectangle at 0x1a268e4550>,
#   <matplotlib.patches.Rectangle at 0x1a268e4be0>,
#   <matplotlib.patches.Rectangle at 0x1a268f02b0>,
#   <matplotlib.patches.Rectangle at 0x1a268f0940>,
#   <matplotlib.patches.Rectangle at 0x1a268f0fd0>,
#   <matplotlib.patches.Rectangle at 0x1a268fb6a0>,
#   <matplotlib.patches.Rectangle at 0x1a268fbd30>,
#   <matplotlib.patches.Rectangle at 0x1a26904400>,
#   <matplotlib.patches.Rectangle at 0x1a26904a90>,
#   <matplotlib.patches.Rectangle at 0x1a26911160>,
#   <matplotlib.patches.Rectangle at 0x1a269117f0>,
#   <matplotlib.patches.Rectangle at 0x1a26911e80>,
#   <matplotlib.patches.Rectangle at 0x1a2691a550>,
#   <matplotlib.patches.Rectangle at 0x1a2691abe0>,
#   <matplotlib.patches.Rectangle at 0x1a269252b0>,
#   <matplotlib.patches.Rectangle at 0x1a26925940>,
#   <matplotlib.patches.Rectangle at 0x1a26925fd0>,
#   <matplotlib.patches.Rectangle at 0x1a2692e6a0>,
#   <matplotlib.patches.Rectangle at 0x1a2692ed30>,
#   <matplotlib.patches.Rectangle at 0x1a26938400>,
#   <matplotlib.patches.Rectangle at 0x1a26938a90>,
#   <matplotlib.patches.Rectangle at 0x1a26941160>,
#   <matplotlib.patches.Rectangle at 0x1a269417f0>,
#   <matplotlib.patches.Rectangle at 0x1a26941e80>,
#   <matplotlib.patches.Rectangle at 0x1a2694c550>,
#   <matplotlib.patches.Rectangle at 0x1a2694cbe0>,
#   <matplotlib.patches.Rectangle at 0x1a269572b0>,
#   <matplotlib.patches.Rectangle at 0x1a26957940>,
#   <matplotlib.patches.Rectangle at 0x1a26957fd0>,
#   <matplotlib.patches.Rectangle at 0x1a269616a0>,
#   <matplotlib.patches.Rectangle at 0x1a26961d30>,
#   <matplotlib.patches.Rectangle at 0x1a2696a400>,
#   <matplotlib.patches.Rectangle at 0x1a2696aa90>,
#   <matplotlib.patches.Rectangle at 0x1a26976160>,
#   <matplotlib.patches.Rectangle at 0x1a269767f0>,
#   <matplotlib.patches.Rectangle at 0x1a26976e80>,
#   <matplotlib.patches.Rectangle at 0x1a26980550>,
#   <matplotlib.patches.Rectangle at 0x1a26980be0>,
#   <matplotlib.patches.Rectangle at 0x1a2698a2b0>,
#   <matplotlib.patches.Rectangle at 0x1a2698a940>,
#   <matplotlib.patches.Rectangle at 0x1a2698afd0>,
#   <matplotlib.patches.Rectangle at 0x1a269936a0>,
#   <matplotlib.patches.Rectangle at 0x1a26993d30>,
#   <matplotlib.patches.Rectangle at 0x1a2699d400>,
#   <matplotlib.patches.Rectangle at 0x1a2699da90>,
#   <matplotlib.patches.Rectangle at 0x1a269a7160>,
#   <matplotlib.patches.Rectangle at 0x1a269a77f0>,
#   <matplotlib.patches.Rectangle at 0x1a269a7e80>,
#   <matplotlib.patches.Rectangle at 0x1a269b3550>,
#   <matplotlib.patches.Rectangle at 0x1a269b3be0>,
#   <matplotlib.patches.Rectangle at 0x1a269bd2b0>,
#   <matplotlib.patches.Rectangle at 0x1a269bd940>,
#   <matplotlib.patches.Rectangle at 0x1a269bdfd0>,
#   <matplotlib.patches.Rectangle at 0x1a269c76a0>,
#   <matplotlib.patches.Rectangle at 0x1a269c7d30>,
#   <matplotlib.patches.Rectangle at 0x1a269d1400>,
#   <matplotlib.patches.Rectangle at 0x1a269d1a90>,
#   <matplotlib.patches.Rectangle at 0x1a269dc160>,
#   <matplotlib.patches.Rectangle at 0x1a269dc7f0>,
#   <matplotlib.patches.Rectangle at 0x1a269dce80>,
#   <matplotlib.patches.Rectangle at 0x1a269e4550>,
#   <matplotlib.patches.Rectangle at 0x1a269e4be0>,
#   <matplotlib.patches.Rectangle at 0x1a269ee2b0>,
#   <matplotlib.patches.Rectangle at 0x1a269ee940>,
#   <matplotlib.patches.Rectangle at 0x1a269eefd0>,
#   <matplotlib.patches.Rectangle at 0x1a269f96a0>,
#   <matplotlib.patches.Rectangle at 0x1a269f9d30>,
#   <matplotlib.patches.Rectangle at 0x1a26a05400>])

# %%
ohlc= filtered_data10[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()

f1, ax = plt.subplots(figsize = (20,10))
ax.set_xlabel('relative_time')
ax.set_ylabel('scroll_offset')
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1a26a9c080>,
#   <matplotlib.lines.Line2D at 0x1a26a9c6a0>,
#   <matplotlib.lines.Line2D at 0x1a26a9cd30>,
#   <matplotlib.lines.Line2D at 0x1a26a7b400>,
#   <matplotlib.lines.Line2D at 0x1a26a7ba90>,
#   <matplotlib.lines.Line2D at 0x1a26aa4160>,
#   <matplotlib.lines.Line2D at 0x1a26aa47f0>,
#   <matplotlib.lines.Line2D at 0x1a26aa4e80>,
#   <matplotlib.lines.Line2D at 0x1a26ab7550>,
#   <matplotlib.lines.Line2D at 0x1a26ab7be0>],
#  [<matplotlib.patches.Rectangle at 0x1a26a9c1d0>,
#   <matplotlib.patches.Rectangle at 0x1a26a9c860>,
#   <matplotlib.patches.Rectangle at 0x1a26a9cef0>,
#   <matplotlib.patches.Rectangle at 0x1a26a7b5c0>,
#   <matplotlib.patches.Rectangle at 0x1a26a7bc50>,
#   <matplotlib.patches.Rectangle at 0x1a26aa4320>,
#   <matplotlib.patches.Rectangle at 0x1a26aa49b0>,
#   <matplotlib.patches.Rectangle at 0x1a26ab7080>,
#   <matplotlib.patches.Rectangle at 0x1a26ab7710>,
#   <matplotlib.patches.Rectangle at 0x1a26ab7da0>])

# %%
ohlc= filtered_data11[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()

f1, ax = plt.subplots(figsize = (20,10))
ax.set_xlabel('relative_time')
ax.set_ylabel('scroll_offset')
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1a26dd0f60>,
#   <matplotlib.lines.Line2D at 0x1a26dd95c0>,
#   <matplotlib.lines.Line2D at 0x1a26dd9c50>,
#   <matplotlib.lines.Line2D at 0x1a27092320>,
#   <matplotlib.lines.Line2D at 0x1a270929b0>,
#   <matplotlib.lines.Line2D at 0x1a2709c080>,
#   <matplotlib.lines.Line2D at 0x1a2709c710>,
#   <matplotlib.lines.Line2D at 0x1a2709cda0>,
#   <matplotlib.lines.Line2D at 0x1a270a7470>,
#   <matplotlib.lines.Line2D at 0x1a270a7b00>,
#   <matplotlib.lines.Line2D at 0x1a270b21d0>,
#   <matplotlib.lines.Line2D at 0x1a270b2860>,
#   <matplotlib.lines.Line2D at 0x1a270b2ef0>,
#   <matplotlib.lines.Line2D at 0x1a270ba5c0>,
#   <matplotlib.lines.Line2D at 0x1a270bac50>,
#   <matplotlib.lines.Line2D at 0x1a270c3320>,
#   <matplotlib.lines.Line2D at 0x1a270c39b0>,
#   <matplotlib.lines.Line2D at 0x1a270cc080>,
#   <matplotlib.lines.Line2D at 0x1a270cc710>],
#  [<matplotlib.patches.Rectangle at 0x1a26dd90f0>,
#   <matplotlib.patches.Rectangle at 0x1a26dd9780>,
#   <matplotlib.patches.Rectangle at 0x1a26dd9e10>,
#   <matplotlib.patches.Rectangle at 0x1a270924e0>,
#   <matplotlib.patches.Rectangle at 0x1a27092b70>,
#   <matplotlib.patches.Rectangle at 0x1a2709c240>,
#   <matplotlib.patches.Rectangle at 0x1a2709c8d0>,
#   <matplotlib.patches.Rectangle at 0x1a2709cf60>,
#   <matplotlib.patches.Rectangle at 0x1a270a7630>,
#   <matplotlib.patches.Rectangle at 0x1a270a7cc0>,
#   <matplotlib.patches.Rectangle at 0x1a270b2390>,
#   <matplotlib.patches.Rectangle at 0x1a270b2a20>,
#   <matplotlib.patches.Rectangle at 0x1a270ba0f0>,
#   <matplotlib.patches.Rectangle at 0x1a270ba780>,
#   <matplotlib.patches.Rectangle at 0x1a270bae10>,
#   <matplotlib.patches.Rectangle at 0x1a270c34e0>,
#   <matplotlib.patches.Rectangle at 0x1a270c3b70>,
#   <matplotlib.patches.Rectangle at 0x1a270cc240>,
#   <matplotlib.patches.Rectangle at 0x1a270cc8d0>])

# %%
ohlc= filtered_data12[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()

f1, ax = plt.subplots(figsize = (20,10))
ax.set_xlabel('relative_time')
ax.set_ylabel('scroll_offset')
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1a27138e80>,
#   <matplotlib.lines.Line2D at 0x1a271404e0>,
#   <matplotlib.lines.Line2D at 0x1a27140b70>,
#   <matplotlib.lines.Line2D at 0x1a27149240>,
#   <matplotlib.lines.Line2D at 0x1a271498d0>,
#   <matplotlib.lines.Line2D at 0x1a27149f60>,
#   <matplotlib.lines.Line2D at 0x1a27402630>,
#   <matplotlib.lines.Line2D at 0x1a27402cc0>,
#   <matplotlib.lines.Line2D at 0x1a2740e390>,
#   <matplotlib.lines.Line2D at 0x1a2740ea20>,
#   <matplotlib.lines.Line2D at 0x1a274180f0>,
#   <matplotlib.lines.Line2D at 0x1a27418780>,
#   <matplotlib.lines.Line2D at 0x1a27418e10>,
#   <matplotlib.lines.Line2D at 0x1a274224e0>,
#   <matplotlib.lines.Line2D at 0x1a27422b70>,
#   <matplotlib.lines.Line2D at 0x1a2742b240>,
#   <matplotlib.lines.Line2D at 0x1a2742b8d0>,
#   <matplotlib.lines.Line2D at 0x1a2742bf60>,
#   <matplotlib.lines.Line2D at 0x1a27436630>,
#   <matplotlib.lines.Line2D at 0x1a27436cc0>,
#   <matplotlib.lines.Line2D at 0x1a2743f390>,
#   <matplotlib.lines.Line2D at 0x1a2743fa20>,
#   <matplotlib.lines.Line2D at 0x1a274490f0>,
#   <matplotlib.lines.Line2D at 0x1a27449780>,
#   <matplotlib.lines.Line2D at 0x1a27449e10>,
#   <matplotlib.lines.Line2D at 0x1a274544e0>,
#   <matplotlib.lines.Line2D at 0x1a27454b70>,
#   <matplotlib.lines.Line2D at 0x1a2745f240>,
#   <matplotlib.lines.Line2D at 0x1a2745f8d0>,
#   <matplotlib.lines.Line2D at 0x1a2745ff60>,
#   <matplotlib.lines.Line2D at 0x1a27469630>,
#   <matplotlib.lines.Line2D at 0x1a27469cc0>,
#   <matplotlib.lines.Line2D at 0x1a27473390>,
#   <matplotlib.lines.Line2D at 0x1a27473a20>,
#   <matplotlib.lines.Line2D at 0x1a2747e0f0>,
#   <matplotlib.lines.Line2D at 0x1a2747e780>,
#   <matplotlib.lines.Line2D at 0x1a2747ee10>,
#   <matplotlib.lines.Line2D at 0x1a2745b4e0>,
#   <matplotlib.lines.Line2D at 0x1a2745bb70>,
#   <matplotlib.lines.Line2D at 0x1a27491240>,
#   <matplotlib.lines.Line2D at 0x1a274918d0>,
#   <matplotlib.lines.Line2D at 0x1a27491f60>,
#   <matplotlib.lines.Line2D at 0x1a2749b630>,
#   <matplotlib.lines.Line2D at 0x1a2749bcc0>,
#   <matplotlib.lines.Line2D at 0x1a274a6390>,
#   <matplotlib.lines.Line2D at 0x1a274a6a20>,
#   <matplotlib.lines.Line2D at 0x1a274af0f0>,
#   <matplotlib.lines.Line2D at 0x1a274af780>,
#   <matplotlib.lines.Line2D at 0x1a274afe10>,
#   <matplotlib.lines.Line2D at 0x1a274bb4e0>,
#   <matplotlib.lines.Line2D at 0x1a274bbb70>,
#   <matplotlib.lines.Line2D at 0x1a274c5240>,
#   <matplotlib.lines.Line2D at 0x1a274c58d0>,
#   <matplotlib.lines.Line2D at 0x1a274c5f60>,
#   <matplotlib.lines.Line2D at 0x1a274d0630>,
#   <matplotlib.lines.Line2D at 0x1a274d0cc0>,
#   <matplotlib.lines.Line2D at 0x1a274d9390>,
#   <matplotlib.lines.Line2D at 0x1a274d9a20>,
#   <matplotlib.lines.Line2D at 0x1a274e20f0>,
#   <matplotlib.lines.Line2D at 0x1a274e2780>,
#   <matplotlib.lines.Line2D at 0x1a274e2e10>,
#   <matplotlib.lines.Line2D at 0x1a274ec4e0>,
#   <matplotlib.lines.Line2D at 0x1a274ecb70>,
#   <matplotlib.lines.Line2D at 0x1a274f6240>,
#   <matplotlib.lines.Line2D at 0x1a274f68d0>,
#   <matplotlib.lines.Line2D at 0x1a274f6f60>],
#  [<matplotlib.patches.Rectangle at 0x1a27138fd0>,
#   <matplotlib.patches.Rectangle at 0x1a271406a0>,
#   <matplotlib.patches.Rectangle at 0x1a27140d30>,
#   <matplotlib.patches.Rectangle at 0x1a27149400>,
#   <matplotlib.patches.Rectangle at 0x1a27149a90>,
#   <matplotlib.patches.Rectangle at 0x1a27402160>,
#   <matplotlib.patches.Rectangle at 0x1a274027f0>,
#   <matplotlib.patches.Rectangle at 0x1a27402e80>,
#   <matplotlib.patches.Rectangle at 0x1a2740e550>,
#   <matplotlib.patches.Rectangle at 0x1a2740ebe0>,
#   <matplotlib.patches.Rectangle at 0x1a274182b0>,
#   <matplotlib.patches.Rectangle at 0x1a27418940>,
#   <matplotlib.patches.Rectangle at 0x1a27418fd0>,
#   <matplotlib.patches.Rectangle at 0x1a274226a0>,
#   <matplotlib.patches.Rectangle at 0x1a27422d30>,
#   <matplotlib.patches.Rectangle at 0x1a2742b400>,
#   <matplotlib.patches.Rectangle at 0x1a2742ba90>,
#   <matplotlib.patches.Rectangle at 0x1a27436160>,
#   <matplotlib.patches.Rectangle at 0x1a274367f0>,
#   <matplotlib.patches.Rectangle at 0x1a27436e80>,
#   <matplotlib.patches.Rectangle at 0x1a2743f550>,
#   <matplotlib.patches.Rectangle at 0x1a2743fbe0>,
#   <matplotlib.patches.Rectangle at 0x1a274492b0>,
#   <matplotlib.patches.Rectangle at 0x1a27449940>,
#   <matplotlib.patches.Rectangle at 0x1a27449fd0>,
#   <matplotlib.patches.Rectangle at 0x1a274546a0>,
#   <matplotlib.patches.Rectangle at 0x1a27454d30>,
#   <matplotlib.patches.Rectangle at 0x1a2745f400>,
#   <matplotlib.patches.Rectangle at 0x1a2745fa90>,
#   <matplotlib.patches.Rectangle at 0x1a27469160>,
#   <matplotlib.patches.Rectangle at 0x1a274697f0>,
#   <matplotlib.patches.Rectangle at 0x1a27469e80>,
#   <matplotlib.patches.Rectangle at 0x1a27473550>,
#   <matplotlib.patches.Rectangle at 0x1a27473be0>,
#   <matplotlib.patches.Rectangle at 0x1a2747e2b0>,
#   <matplotlib.patches.Rectangle at 0x1a2747e940>,
#   <matplotlib.patches.Rectangle at 0x1a2747efd0>,
#   <matplotlib.patches.Rectangle at 0x1a2745b6a0>,
#   <matplotlib.patches.Rectangle at 0x1a2745bd30>,
#   <matplotlib.patches.Rectangle at 0x1a27491400>,
#   <matplotlib.patches.Rectangle at 0x1a27491a90>,
#   <matplotlib.patches.Rectangle at 0x1a2749b160>,
#   <matplotlib.patches.Rectangle at 0x1a2749b7f0>,
#   <matplotlib.patches.Rectangle at 0x1a2749be80>,
#   <matplotlib.patches.Rectangle at 0x1a274a6550>,
#   <matplotlib.patches.Rectangle at 0x1a274a6be0>,
#   <matplotlib.patches.Rectangle at 0x1a274af2b0>,
#   <matplotlib.patches.Rectangle at 0x1a274af940>,
#   <matplotlib.patches.Rectangle at 0x1a274affd0>,
#   <matplotlib.patches.Rectangle at 0x1a274bb6a0>,
#   <matplotlib.patches.Rectangle at 0x1a274bbd30>,
#   <matplotlib.patches.Rectangle at 0x1a274c5400>,
#   <matplotlib.patches.Rectangle at 0x1a274c5a90>,
#   <matplotlib.patches.Rectangle at 0x1a274d0160>,
#   <matplotlib.patches.Rectangle at 0x1a274d07f0>,
#   <matplotlib.patches.Rectangle at 0x1a274d0e80>,
#   <matplotlib.patches.Rectangle at 0x1a274d9550>,
#   <matplotlib.patches.Rectangle at 0x1a274d9be0>,
#   <matplotlib.patches.Rectangle at 0x1a274e22b0>,
#   <matplotlib.patches.Rectangle at 0x1a274e2940>,
#   <matplotlib.patches.Rectangle at 0x1a274e2fd0>,
#   <matplotlib.patches.Rectangle at 0x1a274ec6a0>,
#   <matplotlib.patches.Rectangle at 0x1a274ecd30>,
#   <matplotlib.patches.Rectangle at 0x1a274f6400>,
#   <matplotlib.patches.Rectangle at 0x1a274f6a90>,
#   <matplotlib.patches.Rectangle at 0x1a27501160>])

# %%
ohlc= filtered_data13[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()

f1, ax = plt.subplots(figsize = (20,10))
ax.set_xlabel('relative_time')
ax.set_ylabel('scroll_offset')
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1a27584fd0>,
#   <matplotlib.lines.Line2D at 0x1a27584550>,
#   <matplotlib.lines.Line2D at 0x1a27582278>,
#   <matplotlib.lines.Line2D at 0x1a27582908>,
#   <matplotlib.lines.Line2D at 0x1a27582f98>,
#   <matplotlib.lines.Line2D at 0x1a27595668>,
#   <matplotlib.lines.Line2D at 0x1a27595cf8>,
#   <matplotlib.lines.Line2D at 0x1a2759f3c8>,
#   <matplotlib.lines.Line2D at 0x1a2759fa58>,
#   <matplotlib.lines.Line2D at 0x1a275aa128>,
#   <matplotlib.lines.Line2D at 0x1a275aa7b8>,
#   <matplotlib.lines.Line2D at 0x1a275aae48>,
#   <matplotlib.lines.Line2D at 0x1a275b3518>,
#   <matplotlib.lines.Line2D at 0x1a275b3ba8>,
#   <matplotlib.lines.Line2D at 0x1a275bb278>,
#   <matplotlib.lines.Line2D at 0x1a275bb908>,
#   <matplotlib.lines.Line2D at 0x1a275bbf98>],
#  [<matplotlib.patches.Rectangle at 0x1a27584080>,
#   <matplotlib.patches.Rectangle at 0x1a275847b8>,
#   <matplotlib.patches.Rectangle at 0x1a27582438>,
#   <matplotlib.patches.Rectangle at 0x1a27582ac8>,
#   <matplotlib.patches.Rectangle at 0x1a27595198>,
#   <matplotlib.patches.Rectangle at 0x1a27595828>,
#   <matplotlib.patches.Rectangle at 0x1a27595eb8>,
#   <matplotlib.patches.Rectangle at 0x1a2759f588>,
#   <matplotlib.patches.Rectangle at 0x1a2759fc18>,
#   <matplotlib.patches.Rectangle at 0x1a275aa2e8>,
#   <matplotlib.patches.Rectangle at 0x1a275aa978>,
#   <matplotlib.patches.Rectangle at 0x1a275b3048>,
#   <matplotlib.patches.Rectangle at 0x1a275b36d8>,
#   <matplotlib.patches.Rectangle at 0x1a275b3d68>,
#   <matplotlib.patches.Rectangle at 0x1a275bb438>,
#   <matplotlib.patches.Rectangle at 0x1a275bbac8>,
#   <matplotlib.patches.Rectangle at 0x1a2787b198>])

# %%
ohlc= filtered_data14[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()

f1, ax = plt.subplots(figsize = (20,10))
ax.set_xlabel('relative_time')
ax.set_ylabel('scroll_offset')
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1a278e5e48>,
#   <matplotlib.lines.Line2D at 0x1a278ef4a8>,
#   <matplotlib.lines.Line2D at 0x1a278efb38>,
#   <matplotlib.lines.Line2D at 0x1a27ba8208>,
#   <matplotlib.lines.Line2D at 0x1a27ba8898>,
#   <matplotlib.lines.Line2D at 0x1a27ba8f28>,
#   <matplotlib.lines.Line2D at 0x1a27bb45f8>,
#   <matplotlib.lines.Line2D at 0x1a27bb4c88>,
#   <matplotlib.lines.Line2D at 0x1a27bbd358>,
#   <matplotlib.lines.Line2D at 0x1a27bbd9e8>,
#   <matplotlib.lines.Line2D at 0x1a27bc70b8>,
#   <matplotlib.lines.Line2D at 0x1a27bc7748>,
#   <matplotlib.lines.Line2D at 0x1a27bc7dd8>,
#   <matplotlib.lines.Line2D at 0x1a27bd04a8>,
#   <matplotlib.lines.Line2D at 0x1a27bd0b38>,
#   <matplotlib.lines.Line2D at 0x1a27bda208>],
#  [<matplotlib.patches.Rectangle at 0x1a278e5f98>,
#   <matplotlib.patches.Rectangle at 0x1a278ef668>,
#   <matplotlib.patches.Rectangle at 0x1a278efcf8>,
#   <matplotlib.patches.Rectangle at 0x1a27ba83c8>,
#   <matplotlib.patches.Rectangle at 0x1a27ba8a58>,
#   <matplotlib.patches.Rectangle at 0x1a27bb4128>,
#   <matplotlib.patches.Rectangle at 0x1a27bb47b8>,
#   <matplotlib.patches.Rectangle at 0x1a27bb4e48>,
#   <matplotlib.patches.Rectangle at 0x1a27bbd518>,
#   <matplotlib.patches.Rectangle at 0x1a27bbdba8>,
#   <matplotlib.patches.Rectangle at 0x1a27bc7278>,
#   <matplotlib.patches.Rectangle at 0x1a27bc7908>,
#   <matplotlib.patches.Rectangle at 0x1a27bc7f98>,
#   <matplotlib.patches.Rectangle at 0x1a27bd0668>,
#   <matplotlib.patches.Rectangle at 0x1a27bd0cf8>,
#   <matplotlib.patches.Rectangle at 0x1a27bda3c8>])

# %%
ohlc= filtered_data15[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()

f1, ax = plt.subplots(figsize = (20,10))
ax.set_xlabel('relative_time')
ax.set_ylabel('scroll_offset')
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1a27c4d3c8>,
#   <matplotlib.lines.Line2D at 0x1a27c4d9e8>,
#   <matplotlib.lines.Line2D at 0x1a27c550b8>,
#   <matplotlib.lines.Line2D at 0x1a27c55748>,
#   <matplotlib.lines.Line2D at 0x1a27c55dd8>,
#   <matplotlib.lines.Line2D at 0x1a27c5e4a8>,
#   <matplotlib.lines.Line2D at 0x1a27c5eb38>,
#   <matplotlib.lines.Line2D at 0x1a27f1a208>,
#   <matplotlib.lines.Line2D at 0x1a27f1a898>,
#   <matplotlib.lines.Line2D at 0x1a27f1af28>,
#   <matplotlib.lines.Line2D at 0x1a27f255f8>,
#   <matplotlib.lines.Line2D at 0x1a27f25c88>,
#   <matplotlib.lines.Line2D at 0x1a27f2d358>,
#   <matplotlib.lines.Line2D at 0x1a27f2d9e8>,
#   <matplotlib.lines.Line2D at 0x1a27f380b8>,
#   <matplotlib.lines.Line2D at 0x1a27f38748>,
#   <matplotlib.lines.Line2D at 0x1a27f38dd8>,
#   <matplotlib.lines.Line2D at 0x1a27f424a8>,
#   <matplotlib.lines.Line2D at 0x1a27f42b38>,
#   <matplotlib.lines.Line2D at 0x1a27f4b208>,
#   <matplotlib.lines.Line2D at 0x1a27f4b898>,
#   <matplotlib.lines.Line2D at 0x1a27f4bf28>,
#   <matplotlib.lines.Line2D at 0x1a27f565f8>,
#   <matplotlib.lines.Line2D at 0x1a27f56c88>,
#   <matplotlib.lines.Line2D at 0x1a27f60358>,
#   <matplotlib.lines.Line2D at 0x1a27f609e8>,
#   <matplotlib.lines.Line2D at 0x1a27f6c0b8>,
#   <matplotlib.lines.Line2D at 0x1a27f6c748>,
#   <matplotlib.lines.Line2D at 0x1a27f6cdd8>,
#   <matplotlib.lines.Line2D at 0x1a27f754a8>,
#   <matplotlib.lines.Line2D at 0x1a27f75b38>,
#   <matplotlib.lines.Line2D at 0x1a27f7e208>,
#   <matplotlib.lines.Line2D at 0x1a27f7e898>,
#   <matplotlib.lines.Line2D at 0x1a27f7ef28>],
#  [<matplotlib.patches.Rectangle at 0x1a27c4d518>,
#   <matplotlib.patches.Rectangle at 0x1a27c4dba8>,
#   <matplotlib.patches.Rectangle at 0x1a27c55278>,
#   <matplotlib.patches.Rectangle at 0x1a27c55908>,
#   <matplotlib.patches.Rectangle at 0x1a27c55f98>,
#   <matplotlib.patches.Rectangle at 0x1a27c5e668>,
#   <matplotlib.patches.Rectangle at 0x1a27c5ecf8>,
#   <matplotlib.patches.Rectangle at 0x1a27f1a3c8>,
#   <matplotlib.patches.Rectangle at 0x1a27f1aa58>,
#   <matplotlib.patches.Rectangle at 0x1a27f25128>,
#   <matplotlib.patches.Rectangle at 0x1a27f257b8>,
#   <matplotlib.patches.Rectangle at 0x1a27f25e48>,
#   <matplotlib.patches.Rectangle at 0x1a27f2d518>,
#   <matplotlib.patches.Rectangle at 0x1a27f2dba8>,
#   <matplotlib.patches.Rectangle at 0x1a27f38278>,
#   <matplotlib.patches.Rectangle at 0x1a27f38908>,
#   <matplotlib.patches.Rectangle at 0x1a27f38f98>,
#   <matplotlib.patches.Rectangle at 0x1a27f42668>,
#   <matplotlib.patches.Rectangle at 0x1a27f42cf8>,
#   <matplotlib.patches.Rectangle at 0x1a27f4b3c8>,
#   <matplotlib.patches.Rectangle at 0x1a27f4ba58>,
#   <matplotlib.patches.Rectangle at 0x1a27f56128>,
#   <matplotlib.patches.Rectangle at 0x1a27f567b8>,
#   <matplotlib.patches.Rectangle at 0x1a27f56e48>,
#   <matplotlib.patches.Rectangle at 0x1a27f60518>,
#   <matplotlib.patches.Rectangle at 0x1a27f60ba8>,
#   <matplotlib.patches.Rectangle at 0x1a27f6c278>,
#   <matplotlib.patches.Rectangle at 0x1a27f6c908>,
#   <matplotlib.patches.Rectangle at 0x1a27f6cf98>,
#   <matplotlib.patches.Rectangle at 0x1a27f75668>,
#   <matplotlib.patches.Rectangle at 0x1a27f75cf8>,
#   <matplotlib.patches.Rectangle at 0x1a27f7e3c8>,
#   <matplotlib.patches.Rectangle at 0x1a27f7ea58>,
#   <matplotlib.patches.Rectangle at 0x1a27f89128>])

# %%
ohlc= filtered_data16[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()

f1, ax = plt.subplots(figsize = (20,10))
ax.set_xlabel('relative_time')
ax.set_ylabel('scroll_offset')
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1a27ff7d68>,
#   <matplotlib.lines.Line2D at 0x1a280003c8>,
#   <matplotlib.lines.Line2D at 0x1a28000a58>,
#   <matplotlib.lines.Line2D at 0x1a28008128>,
#   <matplotlib.lines.Line2D at 0x1a280087b8>,
#   <matplotlib.lines.Line2D at 0x1a28008e48>,
#   <matplotlib.lines.Line2D at 0x1a28010518>,
#   <matplotlib.lines.Line2D at 0x1a28010ba8>,
#   <matplotlib.lines.Line2D at 0x1a282ca278>,
#   <matplotlib.lines.Line2D at 0x1a282ca908>,
#   <matplotlib.lines.Line2D at 0x1a282caf98>,
#   <matplotlib.lines.Line2D at 0x1a282d5668>,
#   <matplotlib.lines.Line2D at 0x1a282d5cf8>,
#   <matplotlib.lines.Line2D at 0x1a282e13c8>,
#   <matplotlib.lines.Line2D at 0x1a282e1a58>,
#   <matplotlib.lines.Line2D at 0x1a282e9128>,
#   <matplotlib.lines.Line2D at 0x1a282e97b8>,
#   <matplotlib.lines.Line2D at 0x1a282e9e48>,
#   <matplotlib.lines.Line2D at 0x1a282f4518>,
#   <matplotlib.lines.Line2D at 0x1a282f4ba8>,
#   <matplotlib.lines.Line2D at 0x1a282fc278>,
#   <matplotlib.lines.Line2D at 0x1a282fc908>,
#   <matplotlib.lines.Line2D at 0x1a282fcf98>,
#   <matplotlib.lines.Line2D at 0x1a28307668>,
#   <matplotlib.lines.Line2D at 0x1a28307cf8>,
#   <matplotlib.lines.Line2D at 0x1a283103c8>,
#   <matplotlib.lines.Line2D at 0x1a28310a58>,
#   <matplotlib.lines.Line2D at 0x1a2831d128>,
#   <matplotlib.lines.Line2D at 0x1a2831d7b8>,
#   <matplotlib.lines.Line2D at 0x1a2831de48>,
#   <matplotlib.lines.Line2D at 0x1a28327518>,
#   <matplotlib.lines.Line2D at 0x1a28327ba8>],
#  [<matplotlib.patches.Rectangle at 0x1a27ff7eb8>,
#   <matplotlib.patches.Rectangle at 0x1a28000588>,
#   <matplotlib.patches.Rectangle at 0x1a28000c18>,
#   <matplotlib.patches.Rectangle at 0x1a280082e8>,
#   <matplotlib.patches.Rectangle at 0x1a28008978>,
#   <matplotlib.patches.Rectangle at 0x1a28010048>,
#   <matplotlib.patches.Rectangle at 0x1a280106d8>,
#   <matplotlib.patches.Rectangle at 0x1a28010d68>,
#   <matplotlib.patches.Rectangle at 0x1a282ca438>,
#   <matplotlib.patches.Rectangle at 0x1a282caac8>,
#   <matplotlib.patches.Rectangle at 0x1a282d5198>,
#   <matplotlib.patches.Rectangle at 0x1a282d5828>,
#   <matplotlib.patches.Rectangle at 0x1a282d5eb8>,
#   <matplotlib.patches.Rectangle at 0x1a282e1588>,
#   <matplotlib.patches.Rectangle at 0x1a282e1c18>,
#   <matplotlib.patches.Rectangle at 0x1a282e92e8>,
#   <matplotlib.patches.Rectangle at 0x1a282e9978>,
#   <matplotlib.patches.Rectangle at 0x1a282f4048>,
#   <matplotlib.patches.Rectangle at 0x1a282f46d8>,
#   <matplotlib.patches.Rectangle at 0x1a282f4d68>,
#   <matplotlib.patches.Rectangle at 0x1a282fc438>,
#   <matplotlib.patches.Rectangle at 0x1a282fcac8>,
#   <matplotlib.patches.Rectangle at 0x1a28307198>,
#   <matplotlib.patches.Rectangle at 0x1a28307828>,
#   <matplotlib.patches.Rectangle at 0x1a28307eb8>,
#   <matplotlib.patches.Rectangle at 0x1a28310588>,
#   <matplotlib.patches.Rectangle at 0x1a28310c18>,
#   <matplotlib.patches.Rectangle at 0x1a2831d2e8>,
#   <matplotlib.patches.Rectangle at 0x1a2831d978>,
#   <matplotlib.patches.Rectangle at 0x1a28327048>,
#   <matplotlib.patches.Rectangle at 0x1a283276d8>,
#   <matplotlib.patches.Rectangle at 0x1a28327d68>])

# %%
ohlc= filtered_data17[['relative_time', 'max_offset', 'max_offset', 'min_offset','min_offset']].copy()

f1, ax = plt.subplots(figsize = (20,10))
ax.set_xlabel('relative_time')
ax.set_ylabel('scroll_offset')
candlestick_ohlc(ax, ohlc.values, width=.6, colorup='green', colordown='red')
# Out:
# ([<matplotlib.lines.Line2D at 0x1a283a5a58>,
#   <matplotlib.lines.Line2D at 0x1a283ad0b8>,
#   <matplotlib.lines.Line2D at 0x1a283ad748>,
#   <matplotlib.lines.Line2D at 0x1a283addd8>,
#   <matplotlib.lines.Line2D at 0x1a283b84a8>,
#   <matplotlib.lines.Line2D at 0x1a283b8b38>,
#   <matplotlib.lines.Line2D at 0x1a283c3208>,
#   <matplotlib.lines.Line2D at 0x1a283c3898>,
#   <matplotlib.lines.Line2D at 0x1a283c3f28>,
#   <matplotlib.lines.Line2D at 0x1a2867e5f8>,
#   <matplotlib.lines.Line2D at 0x1a2867ec88>,
#   <matplotlib.lines.Line2D at 0x1a28685358>,
#   <matplotlib.lines.Line2D at 0x1a286859e8>,
#   <matplotlib.lines.Line2D at 0x1a2868e0b8>,
#   <matplotlib.lines.Line2D at 0x1a2868e748>,
#   <matplotlib.lines.Line2D at 0x1a2868edd8>,
#   <matplotlib.lines.Line2D at 0x1a286994a8>,
#   <matplotlib.lines.Line2D at 0x1a28699b38>,
#   <matplotlib.lines.Line2D at 0x1a286a4208>,
#   <matplotlib.lines.Line2D at 0x1a286a4898>,
#   <matplotlib.lines.Line2D at 0x1a286a4f28>,
#   <matplotlib.lines.Line2D at 0x1a286ae5f8>,
#   <matplotlib.lines.Line2D at 0x1a286aec88>,
#   <matplotlib.lines.Line2D at 0x1a286b8358>,
#   <matplotlib.lines.Line2D at 0x1a286b89e8>,
#   <matplotlib.lines.Line2D at 0x1a286c20b8>,
#   <matplotlib.lines.Line2D at 0x1a286c2748>,
#   <matplotlib.lines.Line2D at 0x1a286c2dd8>,
#   <matplotlib.lines.Line2D at 0x1a286cd4a8>,
#   <matplotlib.lines.Line2D at 0x1a286cdb38>,
#   <matplotlib.lines.Line2D at 0x1a286d8208>,
#   <matplotlib.lines.Line2D at 0x1a286d8898>,
#   <matplotlib.lines.Line2D at 0x1a286d8f28>,
#   <matplotlib.lines.Line2D at 0x1a286e25f8>,
#   <matplotlib.lines.Line2D at 0x1a286e2c88>,
#   <matplotlib.lines.Line2D at 0x1a286eb358>,
#   <matplotlib.lines.Line2D at 0x1a286eb9e8>,
#   <matplotlib.lines.Line2D at 0x1a286f50b8>,
#   <matplotlib.lines.Line2D at 0x1a286f5748>,
#   <matplotlib.lines.Line2D at 0x1a286f5dd8>,
#   <matplotlib.lines.Line2D at 0x1a287004a8>,
#   <matplotlib.lines.Line2D at 0x1a28700b38>,
#   <matplotlib.lines.Line2D at 0x1a2870a208>,
#   <matplotlib.lines.Line2D at 0x1a2870a898>,
#   <matplotlib.lines.Line2D at 0x1a2870af28>,
#   <matplotlib.lines.Line2D at 0x1a287155f8>,
#   <matplotlib.lines.Line2D at 0x1a28715c88>],
#  [<matplotlib.patches.Rectangle at 0x1a283a5ba8>,
#   <matplotlib.patches.Rectangle at 0x1a283ad278>,
#   <matplotlib.patches.Rectangle at 0x1a283ad908>,
#   <matplotlib.patches.Rectangle at 0x1a283adf98>,
#   <matplotlib.patches.Rectangle at 0x1a283b8668>,
#   <matplotlib.patches.Rectangle at 0x1a283b8cf8>,
#   <matplotlib.patches.Rectangle at 0x1a283c33c8>,
#   <matplotlib.patches.Rectangle at 0x1a283c3a58>,
#   <matplotlib.patches.Rectangle at 0x1a2867e128>,
#   <matplotlib.patches.Rectangle at 0x1a2867e7b8>,
#   <matplotlib.patches.Rectangle at 0x1a2867ee48>,
#   <matplotlib.patches.Rectangle at 0x1a28685518>,
#   <matplotlib.patches.Rectangle at 0x1a28685ba8>,
#   <matplotlib.patches.Rectangle at 0x1a2868e278>,
#   <matplotlib.patches.Rectangle at 0x1a2868e908>,
#   <matplotlib.patches.Rectangle at 0x1a2868ef98>,
#   <matplotlib.patches.Rectangle at 0x1a28699668>,
#   <matplotlib.patches.Rectangle at 0x1a28699cf8>,
#   <matplotlib.patches.Rectangle at 0x1a286a43c8>,
#   <matplotlib.patches.Rectangle at 0x1a286a4a58>,
#   <matplotlib.patches.Rectangle at 0x1a286ae128>,
#   <matplotlib.patches.Rectangle at 0x1a286ae7b8>,
#   <matplotlib.patches.Rectangle at 0x1a286aee48>,
#   <matplotlib.patches.Rectangle at 0x1a286b8518>,
#   <matplotlib.patches.Rectangle at 0x1a286b8ba8>,
#   <matplotlib.patches.Rectangle at 0x1a286c2278>,
#   <matplotlib.patches.Rectangle at 0x1a286c2908>,
#   <matplotlib.patches.Rectangle at 0x1a286c2f98>,
#   <matplotlib.patches.Rectangle at 0x1a286cd668>,
#   <matplotlib.patches.Rectangle at 0x1a286cdcf8>,
#   <matplotlib.patches.Rectangle at 0x1a286d83c8>,
#   <matplotlib.patches.Rectangle at 0x1a286d8a58>,
#   <matplotlib.patches.Rectangle at 0x1a286e2128>,
#   <matplotlib.patches.Rectangle at 0x1a286e27b8>,
#   <matplotlib.patches.Rectangle at 0x1a286e2e48>,
#   <matplotlib.patches.Rectangle at 0x1a286eb518>,
#   <matplotlib.patches.Rectangle at 0x1a286ebba8>,
#   <matplotlib.patches.Rectangle at 0x1a286f5278>,
#   <matplotlib.patches.Rectangle at 0x1a286f5908>,
#   <matplotlib.patches.Rectangle at 0x1a286f5f98>,
#   <matplotlib.patches.Rectangle at 0x1a28700668>,
#   <matplotlib.patches.Rectangle at 0x1a28700cf8>,
#   <matplotlib.patches.Rectangle at 0x1a2870a3c8>,
#   <matplotlib.patches.Rectangle at 0x1a2870aa58>,
#   <matplotlib.patches.Rectangle at 0x1a28715128>,
#   <matplotlib.patches.Rectangle at 0x1a287157b8>,
#   <matplotlib.patches.Rectangle at 0x1a28715e48>])
